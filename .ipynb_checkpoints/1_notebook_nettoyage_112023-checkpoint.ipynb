# %% [markdown]
# # Table des matières
#
# ### [Importations](#T1)
# - [Importing packages](#T1C1)
# - [Importing food data](#T1C2)
# - [Reducing food data size](#T1C3)
#
#
# ### [Overview of the data and cleaning up](#T2)
# - [Overview of the data](#T2C1)
# - [Idée d'application nutritionnelle](#T2C2)
# - [dtypes](#T2C3)
# - [Missing values](#T2C4)
# - [Elimination des features à 100 % de valeurs manquantes](#T2C5)
# - [Data clean-up](#T2C6)
# - [Duplicated datas](#T2C7)
# - [Countries correction](#T2C8)
# - [Distribution of product by countries](#T2C9)
#
# ### [Valeurs aberrantes et manquantes](#T3)
# - [Observation des valeurs nutritives](#T3C1)
# - [Valeurs négatives](#T3C2)
# - [Valeurs à la mauvaise unité](#T3C3)
# - [Correction de la feature Fat_100g](#T3C4)
# - [Correction de la feature saturated-fat_100g](#T3C5)
# - [Correction des la feature carbohydrates](#T3C6)
# - [Correction des features Salt/Sodium](#T3C7)
# - [Valeurs extrêmes : somme des macro-éléments](#T3C8)
# - [Correction et remplissage d'energy-from-fat_100g](#T3C9)
# - [Correction et remplissage d'energy_100g](#T3C10)
# - [Différence entre energy_100g mesurée et entrée](#T3C11)

# %% [markdown]
# ***
# # <a name="T1">Importations</a>

# %% [markdown]
# ### <a name = "T1C1">a. Importing packages </a>

# %%
import subprocess

# Latest upgrade
libraries_to_update = [
    "pandas",
    "numpy",
    "matplotlib",
    "seaborn",
    "scipy",
    #"scikit-learn",
]

for library in libraries_to_update:
    subprocess.check_call(["pip", "install", "--upgrade", library])

# %% [markdown]
# On importe l'ensemble des librairies utilisées lors du projet

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import scipy.stats as st
from scipy import stats
#import statsmodels.api as sm
import copy
from IPython.display import clear_output

# %%
pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-14.0.0-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\33664\desktop\data scientist formation\[projets]\projet nutritionapp\env\lib\site-packages (from pyarrow) (1.26.1)
# Downloading pyarrow-14.0.0-cp311-cp311-win_amd64.whl (24.6 MB)
#    ---------------------------------------- 0.0/24.6 MB ? eta -:--:--
#     --------------------------------------- 0.4/24.6 MB 8.7 MB/s eta 0:00:03
#    - -------------------------------------- 1.0/24.6 MB 10.1 MB/s eta 0:00:03
#    -- ------------------------------------- 1.4/24.6 MB 10.0 MB/s eta 0:00:03
#    --- ------------------------------------ 2.0/24.6 MB 10.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.5/24.6 MB 10.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.1/24.6 MB 11.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 3.7/24.6 MB 11.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/24.6 MB 11.2 MB/s eta 0:00:02
#    ------- -------------------------------- 4.8/24.6 MB 11.3 MB/s eta 0:00:02
#    -------- ------------------------------- 5.3/24.6 MB 11.3 MB/s eta 0:00:02
#    --------- ------------------------------ 5.9/24.6 MB 11.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.4/24.6 MB 11.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.7/24.6 MB 11.5 MB/s eta 0:00:02
#    ------------ --------------------------- 7.5/24.6 MB 11.5 MB/s eta 0:00:02
#    ------------- -------------------------- 8.1/24.6 MB 11.5 MB/s eta 0:00:02
#    -------------- ------------------------- 8.7/24.6 MB 11.5 MB/s eta 0:00:02
#    -------------- ------------------------- 9.2/24.6 MB 11.5 MB/s eta 0:00:02
#    --------------- ------------------------ 9.8/24.6 MB 11.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 10.3/24.6 MB 11.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 10.9/24.6 MB 11.7 MB/s eta 0:00:02
#    ------------------ --------------------- 11.4/24.6 MB 11.7 MB/s eta 0:00:02
#    ------------------- -------------------- 12.0/24.6 MB 11.7 MB/s eta 0:00:02
#    -------------------- ------------------- 12.5/24.6 MB 11.7 MB/s eta 0:00:02
#    --------------------- ------------------ 13.1/24.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 13.6/24.6 MB 11.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 14.2/24.6 MB 11.7 MB/s eta 0:00:01
#    ------------------------ --------------- 14.7/24.6 MB 11.7 MB/s eta 0:00:01
#    ------------------------ --------------- 15.3/24.6 MB 11.7 MB/s eta 0:00:01
#    ------------------------- -------------- 15.9/24.6 MB 11.7 MB/s eta 0:00:01
#    -------------------------- ------------- 16.4/24.6 MB 11.9 MB/s eta 0:00:01
#    --------------------------- ------------ 17.0/24.6 MB 12.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 17.6/24.6 MB 11.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.1/24.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 18.7/24.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------- -------- 19.3/24.6 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 19.7/24.6 MB 11.7 MB/s eta 0:00:01
#    -------------------------------- ------- 20.2/24.6 MB 11.7 MB/s eta 0:00:01
#    --------------------------------- ------ 20.8/24.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.3/24.6 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.9/24.6 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 22.4/24.6 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 23.0/24.6 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 23.6/24.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  24.1/24.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  24.6/24.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  24.6/24.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 24.6/24.6 MB 10.7 MB/s eta 0:00:00
# Installing collected packages: pyarrow
# Successfully installed pyarrow-14.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
libraries = {
    "Pandas" : pd,
    "Numpy" : np,
    "Seaborn" : sns,
    "matplotlib" : matplotlib,
    "scipy" : scipy
}

#Showing packages versions
for lib_name, lib in libraries.items():
    print(f"{lib_name} Version : {lib.__version__}")
# Out:
# Pandas Version : 2.1.2
# Numpy Version : 1.26.1
# Seaborn Version : 0.13.0
# matplotlib Version : 3.8.1
# scipy Version : 1.11.3

# %% [markdown]
# ### <a name = "T1C2">b. Importating food data </a>

# %% [markdown]
# It is a big file, for now, we will choose selected columns

# %%
cols = pd.read_csv("en.openfoodfacts.org.products.csv", sep = "\t", nrows = 1).columns
for c in cols:
    print(c)
# Out:
# code
# url
# creator
# created_t
# created_datetime
# last_modified_t
# last_modified_datetime
# last_modified_by
# product_name
# abbreviated_product_name
# generic_name
# quantity
# packaging
# packaging_tags
# packaging_en
# packaging_text
# brands
# brands_tags
# categories
# categories_tags
# categories_en
# origins
# origins_tags
# origins_en
# manufacturing_places
# manufacturing_places_tags
# labels
# labels_tags
# labels_en
# emb_codes
# emb_codes_tags
# first_packaging_code_geo
# cities
# cities_tags
# purchase_places
# stores
# countries
# countries_tags
# countries_en
# ingredients_text
# ingredients_tags
# ingredients_analysis_tags
# allergens
# allergens_en
# traces
# traces_tags
# traces_en
# serving_size
# serving_quantity
# no_nutrition_data
# additives_n
# additives
# additives_tags
# additives_en
# nutriscore_score
# nutriscore_grade
# nova_group
# pnns_groups_1
# pnns_groups_2
# food_groups
# food_groups_tags
# food_groups_en
# states
# states_tags
# states_en
# brand_owner
# ecoscore_score
# ecoscore_grade
# nutrient_levels_tags
# product_quantity
# owner
# data_quality_errors_tags
# unique_scans_n
# popularity_tags
# completeness
# last_image_t
# last_image_datetime
# main_category
# main_category_en
# image_url
# image_small_url
# image_ingredients_url
# image_ingredients_small_url
# image_nutrition_url
# image_nutrition_small_url
# energy-kj_100g
# energy-kcal_100g
# energy_100g
# energy-from-fat_100g
# fat_100g
# saturated-fat_100g
# butyric-acid_100g
# caproic-acid_100g
# caprylic-acid_100g
# capric-acid_100g
# lauric-acid_100g
# myristic-acid_100g
# palmitic-acid_100g
# stearic-acid_100g
# arachidic-acid_100g
# behenic-acid_100g
# lignoceric-acid_100g
# cerotic-acid_100g
# montanic-acid_100g
# melissic-acid_100g
# unsaturated-fat_100g
# monounsaturated-fat_100g
# polyunsaturated-fat_100g
# omega-3-fat_100g
# alpha-linolenic-acid_100g
# eicosapentaenoic-acid_100g
# docosahexaenoic-acid_100g
# omega-6-fat_100g
# linoleic-acid_100g
# arachidonic-acid_100g
# gamma-linolenic-acid_100g
# dihomo-gamma-linolenic-acid_100g
# omega-9-fat_100g
# oleic-acid_100g
# elaidic-acid_100g
# gondoic-acid_100g
# mead-acid_100g
# erucic-acid_100g
# nervonic-acid_100g
# trans-fat_100g
# cholesterol_100g
# carbohydrates_100g
# sugars_100g
# added-sugars_100g
# sucrose_100g
# glucose_100g
# fructose_100g
# lactose_100g
# maltose_100g
# maltodextrins_100g
# starch_100g
# polyols_100g
# erythritol_100g
# fiber_100g
# soluble-fiber_100g
# insoluble-fiber_100g
# proteins_100g
# casein_100g
# serum-proteins_100g
# nucleotides_100g
# salt_100g
# added-salt_100g
# sodium_100g
# alcohol_100g
# vitamin-a_100g
# beta-carotene_100g
# vitamin-d_100g
# vitamin-e_100g
# vitamin-k_100g
# vitamin-c_100g
# vitamin-b1_100g
# vitamin-b2_100g
# vitamin-pp_100g
# vitamin-b6_100g
# vitamin-b9_100g
# folates_100g
# vitamin-b12_100g
# biotin_100g
# pantothenic-acid_100g
# silica_100g
# bicarbonate_100g
# potassium_100g
# chloride_100g
# calcium_100g
# phosphorus_100g
# iron_100g
# magnesium_100g
# zinc_100g
# copper_100g
# manganese_100g
# fluoride_100g
# selenium_100g
# chromium_100g
# molybdenum_100g
# iodine_100g
# caffeine_100g
# taurine_100g
# ph_100g
# fruits-vegetables-nuts_100g
# fruits-vegetables-nuts-dried_100g
# fruits-vegetables-nuts-estimate_100g
# fruits-vegetables-nuts-estimate-from-ingredients_100g
# collagen-meat-protein-ratio_100g
# cocoa_100g
# chlorophyl_100g
# carbon-footprint_100g
# carbon-footprint-from-meat-or-fish_100g
# nutrition-score-fr_100g
# nutrition-score-uk_100g
# glycemic-index_100g
# water-hardness_100g
# choline_100g
# phylloquinone_100g
# beta-glucan_100g
# inositol_100g
# carnitine_100g
# sulphate_100g
# nitrate_100g

# %%
# For testings, only 400 k lines will be read
DEBUG = 400000

# %%
selected_cols = ["product_name","pnns_groups_1","pnns_groups_2","countries_en",
                 "nutriscore_score","energy-kcal_100g","energy_100g", "fat_100g", 
                 "saturated-fat_100g", "carbohydrates_100g", 
                 "fiber_100g", "proteins_100g", "salt_100g"]

# %%
# Data are separated by a tab.
# We limit the number of rows for testing, as the file is quite big for the computer setup

data = pd.read_csv("en.openfoodfacts.org.products.csv", sep = "\t", nrows = DEBUG, 
                   usecols = selected_cols)#, engine = 'pyarrow')

# %% [markdown]
# ### <a name = "T1C3">c. Reducing food data size</a>

# %% [markdown]
# We can reduce the size of the data.

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print("Memory usage at the begining : {:.2f} MB".format(start_mem))
    
    for i, col in enumerate(df.columns, start=1):
        col_type = df[col].dtype

        # Calculate the percentage of completion
        completion_percentage = (i / df.shape[1]) * 100

        # Use \r to move the cursor to the beginning of the line and overwrite the previous output
        print(f"({i}/{df.shape[1]}) - {completion_percentage:.2f}% complete", end='\r')

        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print("Memory usage at the end of the optimization {:.2f} MB".format(end_mem))
    print("Reduction of {:.1f}%".format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
#data = reduce_mem_usage(data)
# Out:
# Memory usage at the begining : 99.18 MB
# Memory usage at the end of the optimization 57.18 MB
# Reduction of 42.4%

# %% [markdown]
# ***
# # <a name="T2">Overview of the data and cleaning up </a>

# %% [markdown]
# ### <a name = "T2C1">a. Overview of the data</a>

# %% [markdown]
# Let's see our datas

# %%
print("In this dataset, we have:")
print("Number of rows: ", data.shape[0], "\nNumber of columns: ", data.shape[1])
# Out:
# In this dataset, we have:
# Number of rows:  400000
# Number of columns:  13

# %%
with pd.option_context('display.max_columns', None):
    display(data.head())
    
    display(data.describe())
# Out:
#        product_name countries_en  nutriscore_score            pnns_groups_1  \
# 0    jeunes pousses       France               NaN    Fruits and vegetables
# 1             Andrè      Germany               NaN                  unknown
# 2           L.casei        Spain               NaN                  unknown
# 3              Skyr       France              -5.0  Milk and dairy products
# 4  Vitória crackers       France               NaN                  unknown
#
#     pnns_groups_2  energy-kcal_100g  energy_100g  fat_100g  \
# 0      Vegetables               NaN          NaN       NaN
# 1         unknown             165.0        690.0       2.0
# 2         unknown               NaN          NaN       1.4
# 3  Dairy desserts              57.0        238.0       0.2
# 4         unknown             375.0       1569.0       7.0
#
#    saturated-fat_100g  carbohydrates_100g  fiber_100g  proteins_100g  \
# 0                 NaN                 NaN         NaN            NaN
# 1                2.00                65.0         3.0            1.5
# 2                0.90                 9.8         NaN            2.7
# 3                0.10                 3.9         NaN           10.0
# 4                3.08                70.1         NaN            7.8
#
#    salt_100g
# 0        NaN
# 1        NaN
# 2       0.10
# 3       0.09
# 4       1.40
#        nutriscore_score  energy-kcal_100g    energy_100g       fat_100g  \
# count     197713.000000     361659.000000  362277.000000  361333.000000
# mean           9.197185        264.110504    1104.414489      12.230736
# std            8.856896        310.787882    1299.975018      30.444044
# min          -15.000000          0.000000       0.000000       0.000000
# 25%            1.000000         87.000000     364.000000       0.000000
# 50%           10.000000        253.000000    1058.000000       4.840000
# 75%           16.000000        393.000000    1644.000000      19.000000
# max           40.000000      76000.000000  317984.000000   12000.000000
#
#        saturated-fat_100g  carbohydrates_100g     fiber_100g  proteins_100g  \
# count       339907.000000       361770.000000  261058.000000  361449.000000
# mean             4.421312           32.048288       2.655952       7.576114
# std              8.400788           37.554060       6.616719      19.007149
# min              0.000000            0.000000      -6.700000     -24.000000
# 25%              0.000000            5.882353       0.000000       0.500000
# 50%              1.340000           20.190000       1.200000       4.694836
# 75%              6.593407           58.064500       3.529412      10.710000
# max           1700.000000         8140.000000    1600.000000    8470.000000
#
#            salt_100g
# count  338841.000000
# mean        3.813403
# std       498.100799
# min         0.000000
# 25%         0.112500
# 50%         0.720000
# 75%         1.560284
# max    287500.000000

# %% [markdown]
# Two types of features:
# - **Qualitative**: They will give us additional informations on the products.
#
# - **Quantitative** (They have the tags "_100g" et for most, it is the quantity in the food):
#     - We can already see numerous empty columns (that will be filter out later) and abnormal values

# %% [markdown]
# ### <a name = "T2C2">b. Idée d'application nutritionnelle </a>

# %% [markdown]
# D'après les données disponibles, une idée d'application qu'on pourrait développer :
#
# **Recommander des produits plus sains selon une liste de course**
#
# Par exemple : on a dans la liste "ketchup"
#
# On voudrait qu'à partir de la base de données, on ait une recommandation de ketchup sain, basé sur le nutrition score (plus le nutrition score est faible, plus le produit est supposé être sain), mais également disponible dans le pays.
#
# Il faudrait donc :
# - Avoir les informations du nutrition score
# - Avoir les informations du pays
# - Catégoriser les produits (un ketchup étant une marque, il faudrait identifier des produits similaires)
#
# En plus de cela, on voudrait pouvoir identifier des produits riches en fibres, pauvres en sucres etc
#
# Mettre en avant les produits issus de l'agriculture biologique.

# %% [markdown]
# ### <a name = "T2C3">c. dtypes</a>

# %%
# What are the columns type ?
with pd.option_context('display.max_rows', None):
    display(data.dtypes)
# Out:
# product_name           object
# countries_en           object
# nutriscore_score      float64
# pnns_groups_1          object
# pnns_groups_2          object
# energy-kcal_100g      float64
# energy_100g           float64
# fat_100g              float64
# saturated-fat_100g    float64
# carbohydrates_100g    float64
# fiber_100g            float64
# proteins_100g         float64
# salt_100g             float64
# dtype: object

# %% [markdown]
# We can transform some in categorical columns

# %%
categ_columns = ['product_name', 'countries_en', 'pnns_groups_1', 'pnns_groups_2']
data[categ_columns] = data[categ_columns].apply(lambda x: x.astype("category"))

# %%
data[categ_columns].dtypes
# Out:
# product_name     category
# countries_en     category
# pnns_groups_1    category
# pnns_groups_2    category
# dtype: object

# %% [markdown]
# ### Observations :
#
# - Il y a des colonnes qui ne sont pas du bon type (float64 au lieu d'object). On va corriger ça.

# %%
"""liste_feat = ["no_nutriments","nutrition_grade_uk","ingredients_that_may_be_from_palm_oil","ingredients_from_palm_oil","no_nutriments"]

display(data[liste_feat].dtypes)
data = data.astype({"no_nutriments":"object","nutrition_grade_uk":"object","ingredients_that_may_be_from_palm_oil":"object","ingredients_from_palm_oil":"object","no_nutriments":"object"})
display(data[liste_feat].dtypes)"""
# Out:
# 'liste_feat = ["no_nutriments","nutrition_grade_uk","ingredients_that_may_be_from_palm_oil","ingredients_from_palm_oil","no_nutriments"]\n\ndisplay(data[liste_feat].dtypes)\ndata = data.astype({"no_nutriments":"object","nutrition_grade_uk":"object","ingredients_that_may_be_from_palm_oil":"object","ingredients_from_palm_oil":"object","no_nutriments":"object"})\ndisplay(data[liste_feat].dtypes)'

# %% [markdown]
# ### <a name = "T2C4">d. Missing values</a>

# %% [markdown]
# We already saw some missing values

# %%
total_missing_values = data.isnull().sum().sum()
total_data = data.shape[0]*data.shape[1]
missing_percent = (total_missing_values /total_data*100)
print("There are %.1f %% missing values in the dataset" %missing_percent)
# Out:
# There are 12.7 % missing values in the dataset

# %%
## Fonction permettant d'afficher le pourcentage de valeurs manquante par colonnes sous la forme d'un barplot

def valeurs_manquantes_graph(df, element):
    
    #element : "row" ou "column"
    #Si element = row, on analyse le degré de complétude par ligne
    #Si element = column, on analyse le pourcentage de données manquantes par colonnes
    
    
    if element == "column":
        # On créé une liste qui va accueillir le % de données manquantes par feature
        # On parcours les colonnes du dataframe et on calcule le pourcentage de valeurs manquantes
        donnees_manquantes = [[col, df[col].isnull().sum() / df.shape[0] * 100] for col in df.columns]

        #On transforme notre liste contenant les données manquantes en dataframe
        donnees_manquantes = pd.DataFrame(donnees_manquantes, columns = ['Features', 'Pourcentage manquant'])

        #on trie ensuite les données par le pourcentage de données manquantes
        donnees_manquantes.sort_values("Pourcentage manquant", ascending = False, inplace = True)
    
        hauteur = df.columns.shape[0] / 4
    
        plt.figure(figsize=(12,hauteur))
        
        sns.barplot(data = donnees_manquantes, y = "Features", x = "Pourcentage manquant", color = "red", orient = "h")    

        plt.title("Pourcentage de données manquantes par features, N = " + str(df.shape[0]), fontsize = 20)
        plt.xlabel("Pourcentage de données manquantes (%)", fontsize=18)
        plt.ylabel("Features", fontsize=18)
        plt.xlim(0,100)
        plt.show()
    
    elif element == "row":
        # On compte pour chaque ligne le nombre de features pour lesquelles une valeur est entrée

        #Comptage du nombre de valeurs non NaN
        valeur_nonNaN = df.count(axis = 1)
        
        #Comptage du nombre de valeurs NaN
        valeur_NaN = valeur_nonNaN[valeur_nonNaN == 0]

        #Ensuite on calcul la proportion de complétude
        completude_donnees = valeur_nonNaN / len(df.columns) * 100
        
        print("Il y a %d lignes où nous ne retrouvons aucune valeur entrée" %valeur_NaN.shape[0])

        # On regarde la dispersion des données
        print("Statistiques sur la complétude des données :")
        display(completude_donnees.describe())

        # On affiche les résultats dans une figure

        plt.figure(figsize=(12,8))
        
        sns.histplot(data = completude_donnees, bins = len(df.columns))    
        
        plt.title("Distribution du nombre de lignes \npar features remplies, N_features = " + str(len(df.columns)), fontsize = 20)
        plt.xlabel("Nombre de features remplies (%)", fontsize=18)
        plt.ylabel("Nombre de lignes, n = " + str(df.shape[0]), fontsize=18)
        plt.show()
        
    else :
        print("N'a pu rien afficher")
        print("La fonction prend en arguement /element/ qui ne prend comme valeurs /row/ ou /column/")

# %% [markdown]
# On va ensuite afficher le pourcentage de valeurs manquantes par feature.

# %%
valeurs_manquantes_graph(data,'row')
valeurs_manquantes_graph(data,'column')
# Out:
# Il y a 10 lignes où nous ne retrouvons aucune valeur entrée
# Statistiques sur la complétude des données :
# count    400000.000000
# mean         87.256827
# std          19.860719
# min           0.000000
# 25%          84.615385
# 50%          92.307692
# 75%         100.000000
# max         100.000000
# dtype: float64

# %% [markdown]
# ### Observations :
#
# La majorité des features n'a pas ou peu de valeurs (99-100 %), comme le montre le barplot.
#
# On peut déjà supprimer les features avec 100 % de valeurs manquantes.
#
# On va garder les autres pour l'instant, qui pourraient nous servir à trouver les valeurs aberrantes.

# %% [markdown]
# ### <a name = "T2C5">e. Elimination des features à 100 % de valeurs manquantes</a>

# %%
## Donne accès aux opérateurs
import operator

## Fonction permettant d'éliminer les features selon le(s) critère(s) donné(s)
def eliminationFeature(df, critere_number, critere_ope, feature = 0):
    # Prend en arguments:
        ## df : dataframe à modifier
        ## critere_number : pourcentage sur lequel l'élimination sera réalisée (peut envoyer une liste)
        ## critere_ope : opérator en "" utilisé (peut envoyer une liste)

    # Dictionnaire permettant de convertir critere_ope str en operator
    rel_ops = {
        '>': operator.gt,
        '<': operator.lt,
        '>=': operator.ge,
        '<=': operator.le,
        '==': operator.eq,
        '!=': operator.ne
    }
    
    if feature == 0:
        feature = df.columns
    
    # On calcule le pourcentage de valeurs manquantes par features
    donnees_manquantes = [[col, df[col].isnull().sum() / df.shape[0] * 100] for col in feature]

    #On transforme notre liste contenant les données manquantes en dataframe
    donnees_manquantes = pd.DataFrame(donnees_manquantes, columns = ['Features', 'Pourcentage manquant'])
    
    ## on récupère la liste de feature à éliminer selon le critère
    liste_elimination = donnees_manquantes.loc[rel_ops[critere_ope](donnees_manquantes["Pourcentage manquant"], critere_number) , "Features"]
    
    print("On passe de %d" %df.shape[1], end = " ")
    [df.pop(col) for col in liste_elimination]
    print("à %d features" %df.shape[1])
    print("Avec cette liste de features éliminées :")
    
    with pd.option_context('display.max_rows', None):
        display(liste_elimination)
    
    return df

# %%
# On appel notre fonction afin d'éliminer les features avec 100 % de valeurs manquantes
data = eliminationFeature(data, 100, "==")
# Out:
# On passe de 13 à 13 features
# Avec cette liste de features éliminées :
# Series([], Name: Features, dtype: object)

# %% [markdown]
# ### <a name = "T2C6">f. Data clean-up</a>

# %% [markdown]
# We will only keep for now completed products

# %%
print("We going from %d rows" %data.shape[0], end = " ")
data = data[data.isnull().sum(axis = 1) == 0]
print("to %d rows after clean-up" %data.shape[0])
# Out:
# We going from 400000 rows to 166420 rows after clean-up

# %% [markdown]
# Le **nom du produit** est essentiel pour le développement de notre application et en absence de son nom, il serait plus difficile de retrouver le produit. C'est pareil pour le **code**.
#
# On va donc éliminer ces produits.

# %%
"""print("Il y a %d lignes où le nom du produit n'est pas renseigné" %data["product_name"].isnull().sum())

ligne_elimination_index = data.loc[data["product_name"].isnull()].index 

print("On passe de %d" %data.shape[0], end = " ")
data = data.loc[~data.index.isin(ligne_elimination_index)]
print("à %d lignes" %data.shape[0])"""
# Out:
# 'print("Il y a %d lignes où le nom du produit n\'est pas renseigné" %data["product_name"].isnull().sum())\n\nligne_elimination_index = data.loc[data["product_name"].isnull()].index \n\nprint("On passe de %d" %data.shape[0], end = " ")\ndata = data.loc[~data.index.isin(ligne_elimination_index)]\nprint("à %d lignes" %data.shape[0])'

# %%
"""print("Il y a %d lignes où le code du produit n'est pas renseigné" %data["code"].isnull().sum())

ligne_elimination_index = data.loc[data["code"].isnull()].index 

print("On passe de %d" %data.shape[0], end = " ")
data = data.loc[~data.index.isin(ligne_elimination_index)]
print("à %d lignes" %data.shape[0])"""
# Out:
# 'print("Il y a %d lignes où le code du produit n\'est pas renseigné" %data["code"].isnull().sum())\n\nligne_elimination_index = data.loc[data["code"].isnull()].index \n\nprint("On passe de %d" %data.shape[0], end = " ")\ndata = data.loc[~data.index.isin(ligne_elimination_index)]\nprint("à %d lignes" %data.shape[0])'

# %% [markdown]
# Egalement, une **absence totale d'information nutritionnelle** sur les produits est préjudiciable.
#
# Ces produits seront éliminés si 100 % d'information est manquante.

# %%
"""# On récupère les features ayant comme informations les valeurs nutritives (+nutriscore)
poids_cols = [col for col in data.columns if "100g" in col]

valeurs_manquantes_graph(data[poids_cols],"row")"""
# Out:
# '# On récupère les features ayant comme informations les valeurs nutritives (+nutriscore)\npoids_cols = [col for col in data.columns if "100g" in col]\n\nvaleurs_manquantes_graph(data[poids_cols],"row")'

# %%
## Donne accès aux opérateurs
import operator

## Fonction permettant d'éliminer les lignes selon le(s) critère(s) donné(s)
def eliminationRows(df, critere_number, critere_ope, feature = 0):
    # Prend en arguments:
        ## df : dataframe à modifier
        ## feature : df.columns si aucune sous_liste spécifiée
        ## critere_number : pourcentage sur lequel l'élimination sera réalisée (peut envoyer une liste)
        ## 0 = 0 données, 100 = 100% des données remplies
        ## critere_ope : opérator en "" utilisé (peut envoyer une liste)

    # Dictionnaire permettant de convertir critere_ope str en operator
    rel_ops = {
        '>': operator.gt,
        '<': operator.lt,
        '>=': operator.ge,
        '<=': operator.le,
        '==': operator.eq,
        '!=': operator.ne
    }
    
    if feature == 0:
        feature = df.columns
    
    # Comptage du nombre de valeurs entrées par ligne
    valeur_nonNaN = df[feature].count(axis = 1)
    
    # Calcul de la proportion de complétude
    completude_donnees = valeur_nonNaN / len(feature) * 100
    
    # On récupère une liste d'indexes des lignes à éliminer selon le critère
    liste_index_elimination = completude_donnees[rel_ops[critere_ope](completude_donnees, critere_number)].index
    
    print("On passe de %d" %df.shape[0], end = " ")
    # On élimine les lignes qui sont présentes dans la liste récupérée
    df = df.loc[~df.index.isin(liste_index_elimination)]
    print("à %d lignes" %df.shape[0], end = " ")
    print("(- %d)" %liste_index_elimination.shape[0])
    
    return df

# %%
"""# On appel notre fonction permettant d'éliminer les lignes ayant 0 features remplies

data = eliminationRows(data, 0, "==", poids_cols)"""
# Out:
# '# On appel notre fonction permettant d\'éliminer les lignes ayant 0 features remplies\n\ndata = eliminationRows(data, 0, "==", poids_cols)'

# %% [markdown]
# Il y avait donc 41020 lignes sans informations nutritionnelles (>10% de la base de données).

# %% [markdown]
# ### <a name = "T2C7">g. Duplicated datas</a>

# %% [markdown]
# Do we have any duplicated datas ?

# %%
display(data.loc[data.duplicated(keep = False),:])
# Out:
#                                              product_name   countries_en  \
# 1275         The best chocolate chip cookies in the world  United States
# 1276         The best chocolate chip cookies in the world  United States
# 1492    The Madelaine Chocolate Company, Solid Milk Ch...  United States
# 1497    The Madelaine Chocolate Company, Solid Milk Ch...  United States
# 1554                                        Fresh Spinach  United States
# ...                                                   ...            ...
# 399819                                2% reduced fat milk  United States
# 399830                                         Whole milk  United States
# 399845                            Black Bean & Corn Salsa  United States
# 399971                             Extra Virgin Olive Oil  United States
# 399976                             Extra virgin olive oil  United States
#
#         nutriscore_score            pnns_groups_1         pnns_groups_2  \
# 1275                 4.0            Sugary snacks    Biscuits and cakes
# 1276                 4.0            Sugary snacks    Biscuits and cakes
# 1492                24.0            Sugary snacks                Sweets
# 1497                24.0            Sugary snacks                Sweets
# 1554                -8.0                  unknown               unknown
# ...                  ...                      ...                   ...
# 399819               0.0  Milk and dairy products       Milk and yogurt
# 399830               1.0  Milk and dairy products       Milk and yogurt
# 399845               0.0           Fat and sauces  Dressings and sauces
# 399971               5.0           Fat and sauces                  Fats
# 399976               5.0           Fat and sauces                  Fats
#
#         energy-kcal_100g  energy_100g   fat_100g  saturated-fat_100g  \
# 1275               132.0        552.0   6.000000            3.500000
# 1276               132.0        552.0   6.000000            3.500000
# 1492               556.0       2326.0  33.330000           19.440000
# 1497               556.0       2326.0  33.330000           19.440000
# 1554                24.0        100.0   0.000000            0.000000
# ...                  ...          ...        ...                 ...
# 399819              50.0        209.0   2.080000            1.460000
# 399830              62.5        262.0   3.333333            2.083333
# 399845              63.0        264.0   0.000000            0.000000
# 399971             800.0       3347.0  93.333333           13.333333
# 399976             800.0       3350.0  93.300000           13.300000
#
#         carbohydrates_100g  fiber_100g  proteins_100g  salt_100g
# 1275                 17.00         0.0       2.000000   0.125000
# 1276                 17.00         0.0       2.000000   0.125000
# 1492                 58.33         2.8       8.330000   0.207500
# 1497                 58.33         2.8       8.330000   0.207500
# 1554                  3.53         2.4       2.350000   0.190000
# ...                    ...         ...            ...        ...
# 399819                4.58         0.0       3.330000   0.125000
# 399830                5.00         0.0       3.333333   0.130208
# 399845               12.69         3.2       3.170000   1.070000
# 399971                0.00         0.0       0.000000   0.000000
# 399976                0.00         0.0       0.000000   0.000000
#
# [17617 rows x 13 columns]

# %% [markdown]
# Yes, we have some duplicated data. We will have to clean that up.

# %%
# Pour voir les duplicats il faut se baser sur le nom du produit. 
# Certains produits peuvent être vendus avec différentes quantités, on ne veut en garder qu'une référence du produit
# Certains produits peuvent être vendus dans différents pays, on veut garder cette information pour l'instant

#Criteres : on analyse les duplicats sur une liste de ces critères
"""criteres = ["product_name", "countries_tags"] + poids_cols

with pd.option_context('display.max_columns', None):
    display(data.loc[data[criteres].duplicated(keep = False),:].sort_values("product_name", ascending = False))

data.drop_duplicates(subset = criteres, keep = "first", inplace = True)

"""
# Out:
# 'criteres = ["product_name", "countries_tags"] + poids_cols\n\nwith pd.option_context(\'display.max_columns\', None):\n    display(data.loc[data[criteres].duplicated(keep = False),:].sort_values("product_name", ascending = False))\n\ndata.drop_duplicates(subset = criteres, keep = "first", inplace = True)\n\n'

# %%
print("We going from %d rows" %data.shape[0], end = " ")
data.drop_duplicates(keep = "first", inplace = True)
print("to %d rows after clean-up" %data.shape[0])
# Out:
# We going from 166420 rows to 155589 rows after clean-up

# %%
# Les produits ne doivent pas avoir le même code, sauf duplicat

"""with pd.option_context('display.max_columns', None):
    display(data.loc[data["code"].duplicated(keep = False),:].sort_values("code", ascending = False))"""
# Out:
# 'with pd.option_context(\'display.max_columns\', None):\n    display(data.loc[data["code"].duplicated(keep = False),:].sort_values("code", ascending = False))'

# %% [markdown]
# ## Observation :
#
# Des produits aux noms différents ont le même code.
#
# Etant donné qu'ils y en a peu, on les élimine de la base de données.

# %%
"""print("On passe de %d" %data.shape[0], end = " ")
data.drop_duplicates(subset = "code", keep= False, inplace = True)
print("à %d lignes" %data.shape[0])"""
# Out:
# 'print("On passe de %d" %data.shape[0], end = " ")\ndata.drop_duplicates(subset = "code", keep= False, inplace = True)\nprint("à %d lignes" %data.shape[0])'

# %% [markdown]
# ### <a name = "T2C8">h. Countries correction</a>
#
# Countries information will be important, we need to correct any wrongfull entries

# %%
"""donnees_manquantes =[] 

for col in ["countries", "countries_tags", "countries_fr"]:
    donnees_manquantes.append([col,data[col].isnull().sum()])

display(donnees_manquantes)"""
# Out:
# 'donnees_manquantes =[] \n\nfor col in ["countries", "countries_tags", "countries_fr"]:\n    donnees_manquantes.append([col,data[col].isnull().sum()])\n\ndisplay(donnees_manquantes)'

# %% [markdown]
# Il y a quand même quelques valeurs manquantes.
#
# Ca ne concerne que peu de pays, on va les éliminer.

# %%
"""ligne_elimination_index = data[data.countries.isnull()].index

print("On passe de %d" %data.shape[0], end = " ")
data = data.loc[~data.index.isin(ligne_elimination_index)]
print("à %d lignes" %data.shape[0])"""
# Out:
# 'ligne_elimination_index = data[data.countries.isnull()].index\n\nprint("On passe de %d" %data.shape[0], end = " ")\ndata = data.loc[~data.index.isin(ligne_elimination_index)]\nprint("à %d lignes" %data.shape[0])'

# %% [markdown]
# Pour plus de faciliter, et car l'information est redondante, nous allons nous focaliser que sur "countries_fr"

# %%
unique_pays = data.countries_en.unique()
unique_pays
# Out:
# array(['France', 'United States', 'Canada', 'Belgium,France',
#        'France,United States', 'Belgium', 'United Kingdom', 'Italy',
#        'Germany', 'Portugal', 'Germany,United States', 'Bulgaria',
#        'Spain', 'France,United Kingdom',
#        'Belgium,France,Netherlands,United Kingdom', 'Mexico',
#        'Netherlands', 'India', 'Switzerland', 'Germany,Frankreich',
#        'South Africa,United States', 'Australia',
#        'Austria,Germany,Frankreich,Spanien',
#        'Germany,Luxembourg,Deutschland,Spanien',
#        'France,Hungary,United Kingdom', 'Czech Republic,France',
#        'Hungary', 'France,Germany', 'Bolivia,United States',
#        'France,Switzerland,United States', 'Australia,France',
#        'Puerto Rico', 'France,Thailand',
#        'Austria,Germany,Deutschland,Frankreich', 'Germany,Malaysia',
#        'Guam', 'French Polynesia,United States',
#        'United Kingdom,United States', 'Egypt,United States',
#        'Belgium,United States', 'Spain,United States',
#        'Mexico,United States', 'Haiti', 'Singapore',
#        'Croatia,France,Germany,Ireland,Switzerland,United States',
#        'Australia,Belgium,France,Germany,Luxembourg,Switzerland',
#        'Argentina,France,United States', 'Belgium,Spain', 'Norway',
#        'Canada,United Kingdom', 'Canada,United States',
#        'Indonesia,Netherlands,Saudi Arabia,South Korea',
#        'Australia,France,New Zealand', 'French Polynesia',
#        'Australia,United States', 'France,Spain', 'Saudi Arabia',
#        'Pakistan,Arabie-saoudite', 'Switzerland,United States',
#        'Saudi Arabia,السعودية', 'United Arab Emirates', 'Bahrain',
#        'Panama', 'Costa Rica', 'Colombia', 'Hong Kong', 'Martinique',
#        'Argentina,Mexico,United States',
#        'Australia,France,Sweden,United States', 'Nederland',
#        'Canada,France', 'En-us', 'Vietnam',
#        'Bolivia,Mexico,United States', 'Martinique,United States',
#        'Bolivia,France,United States',
#        'France,Thailand,United Kingdom,United States',
#        'Austria,United States', 'Austria,France,United States',
#        'France,Mexico,United States', 'France,Spain,Switzerland',
#        'France,Switzerland,United Kingdom',
#        'France,French Polynesia,United States',
#        'France,Ireland,United Kingdom', 'Philippines', 'Czech Republic',
#        'France,Mexico', 'France,Guadeloupe',
#        'Australia,New Zealand,Singapore,Thailand,United States',
#        'Italy,Switzerland', 'France,Spain,United Kingdom', 'Jersey',
#        'Germany,Switzerland', 'Puerto Rico,United States',
#        'Germany,Ireland,United States', 'France,Spain,United States',
#        'India,Spain,United States', 'Colombia,Spain',
#        'Lebanon,United States',
#        'Bolivia,France,French Polynesia,United States', 'Thailand',
#        'France,French Polynesia', 'United Arab Emirates,United States',
#        'United States,France-united-states',
#        'France,New Caledonia,United States',
#        'France,Germany,United States', 'Thailand,United States',
#        'France-united-states', 'France,Panama,United States',
#        'France,Germany,Switzerland',
#        'Costa Rica,Mexico,Spain,Estados-unidos',
#        'Mexico,Thailand,United States,Francia',
#        'Australia,Canada,France,Germany',
#        'France,Germany,Russia,United Kingdom,United States',
#        'Australia,France,United States',
#        'France,United Kingdom,United States',
#        'France,Germany,Switzerland,United States',
#        'Germany,Spain,United States', 'Netherlands,United States',
#        'Czech Republic,United States', 'France,Norway,Spain',
#        'France,Germany,Spain', 'Germany,Spain,United Kingdom',
#        'Panama,Singapore', 'Malaysia,United States',
#        'Brazil,United States', 'Andorra', 'Morocco',
#        'Sweden,United States', 'Ireland', 'Costa Rica,United States',
#        'France,Sweden,United States', 'Poland', 'Germany,United Kingdom',
#        'France-en-canada', 'Guadeloupe,United States',
#        'Mexico,United States,Francia', 'Trinidad and Tobago',
#        'Germany,Ireland', 'Bermuda', 'Canada,France,United States',
#        'Romania', 'Saudi Arabia,United States', 'Réunion',
#        'China,Hong Kong', 'Spain,United Kingdom', 'Malaysia,Singapore',
#        'Bolivia', 'Bolivia,Ecuador,United States', 'Bolivia,France',
#        'Bolivia,Puerto Rico,United States',
#        'France,United States,Allemagne,Royaume-uni',
#        'Republic-of-macedonia', 'France,Switzerland',
#        'Canada,France,Germany', 'France,Lebanon', 'Qatar',
#        'Saint Martin,United States',
#        'Germany,Japan,Switzerland,United States',
#        'Finland,Germany,Netherlands', 'France,Allemagne,Etats-unis',
#        'Belgium,France,Switzerland,United States',
#        'Germany,Switzerland,United States',
#        'Belgium,Denmark,France,Germany,Spain,United States',
#        'Belgium,Germany,Netherlands,United States',
#        'Belgium,France,Germany,Switzerland,United Kingdom',
#        'Belgium,France,Germany,Italy', 'Belgium,Switzerland',
#        'Belgium,Germany,Switzerland', 'Belgium,France,Germany',
#        'Belgium,France,Germany,Spain,Switzerland,United Kingdom',
#        'Belgium,Germany,United Kingdom', 'Belgium,France,Spain',
#        'Hong Kong,United States', 'France,Guyana,United States',
#        'Italy,Spain', 'France,Italy', 'Netherlands,United Kingdom',
#        'France,Germany,Mexico,Sweden,Switzerland,United States',
#        'China,France,United States', 'Japan', 'Canada,Mexico',
#        'Mexico,Panama', 'Dominican Republic', 'United States,Etats-unis',
#        'Belgium,France,United States',
#        'Barbados,France,Spain,United States', 'El Salvador',
#        'France,Ireland,United States', 'Bolivia,Canada,United States',
#        'Bolivia,France,United Kingdom,United States',
#        'Germany,Mexico,United States', 'New Caledonia,Singapore',
#        'Hong Kong,Singapore', 'France,French Polynesia,Taiwan',
#        'France,Saint Kitts and Nevis', 'New Caledonia',
#        'Panama,United States', 'Hong Kong,Kuwait', 'Guadeloupe',
#        'Pakistan', 'Barbados', 'Brazil,France', 'Guatemala',
#        'Haiti,United States', 'France,New Caledonia',
#        'Jamaica,United States', 'Bahrain,United States',
#        'Japan,United States', 'France,Germany,Spain,United States',
#        'Bolivia,French Polynesia,United States', 'Mexico,Spain',
#        'France,Taiwan,United States', 'Australia,New Zealand', 'China',
#        'Lebanon', 'France,Oman', 'Egypt',
#        'Trinidad and Tobago,United States',
#        'Virgin Islands of the United States',
#        'Australia,Germany,United States', 'Francia-espana',
#        'France,Germany,Sweden', 'Sweden,Switzerland', 'Mark',
#        'Portugal,United States', 'Senegal',
#        'Bolivia,Dominican Republic,United States', 'North-carolina',
#        'Jersey,United Kingdom', 'Italy,United States', 'France,Kuwait',
#        'Austria,France,French Polynesia,Netherlands,Switzerland',
#        'France,Italy,United States',
#        'France,Germany,United Kingdom,United States',
#        'France,Mexico,Spain,United States', 'France,Mexico,Spain',
#        'France,Thailand,United Kingdom', 'Bolivia,Spain,United States',
#        'Bolivia,France,Germany,Hong Kong,United States',
#        'Bolivia,Israel,Philippines,United States',
#        'Bolivia,Israel,United States', 'France,Puerto Rico,United States',
#        'Philippines,United States', 'Kuwait,United States',
#        'Argentina,Bolivia,Colombia,Costa Rica,Dominican Republic,El Salvador,Guatemala,Honduras,Mexico,Nicaragua,Panama,Paraguay,Peru,United States,Uruguay',
#        'Bolivia,Mexico',
#        'Argentina,Bolivia,Chile,Colombia,Costa Rica,Dominican Republic,El Salvador,Guatemala,Honduras,Mexico,Nicaragua,Panama,Paraguay,Peru,United States,Uruguay,Venezuela',
#        'Argentina,Bolivia,Colombia,Costa Rica,Panama,Paraguay,Peru,Uruguay',
#        'France,United Arab Emirates,United States',
#        'Sint Maarten,United States', 'Anguilla,United States',
#        'Bolivia,El Salvador,Mexico,United States',
#        'Argentina,Bolivia,Colombia,Costa Rica,Dominican Republic,El Salvador,Guatemala,Honduras,Mexico,Nicaragua,Panama,Paraguay,United States,Uruguay',
#        'Bolivia,Colombia,Costa Rica,Dominican Republic,El Salvador,Guatemala,Honduras,Jamaica,Mexico,Nicaragua,Panama,Peru,Puerto Rico,Spain,Trinidad and Tobago,United States',
#        'Bolivia,Colombia,Costa Rica,Dominican Republic,El Salvador,Honduras,Jamaica,Mexico,Nicaragua,Panama,Peru,Puerto Rico,Trinidad and Tobago,United States',
#        'Peru', 'France,Hong Kong,Singapore', 'France,Israel,Mexico',
#        'United States,En', 'Niger', 'France,Germany,Poland,Switzerland',
#        'Austria,France,Germany,Spain',
#        'France,Germany,Switzerland,United States,En',
#        'Bolivia,Germany,Spain,United States', 'Myanmar,United States',
#        'Germany,Italy,Sweden,United Kingdom',
#        'Germany,Italy,Switzerland,United States',
#        'France,Germany,United Kingdom', 'Spain,Switzerland,United States',
#        'Belgium,Switzerland,United Kingdom,United States',
#        'Switzerland,United Kingdom,United States',
#        'Czech Republic,France,Thailand',
#        'Bolivia,Switzerland,United States', 'Colombia,United States',
#        'Bolivia,Colombia,Germany,Spain,United States',
#        'Canada,Switzerland', "Côte d'Ivoire,United States",
#        'Bolivia,France,Germany,United States',
#        'Germany,Poland,United States', 'Antigua and Barbuda',
#        'The Bahamas', 'Bolivia,Germany,United States', 'Denmark',
#        'Sweden', 'Saint Lucia,United States',
#        'Anguilla,Saint Kitts and Nevis,United States',
#        'Cambodia,United States', 'Peru,United States', 'Germany,Greece',
#        'Greece', 'South Africa', 'Canada,France,Mexico,United States',
#        'France,Royaume-uni', 'France,Ireland',
#        'Switzerland,United Kingdom', 'Nicaragua,United States',
#        'Turkey,United States', 'Netherlands,Panama',
#        'Bolivia,Costa Rica,United States', 'Russia,United States',
#        'Angola,France,United States',
#        'Austria,France,Spain,United States', 'Greece,United States',
#        'Bermuda,United States', 'Brazil,France,United States',
#        'France,Singapore,United States',
#        'Austria,Belgium,Germany,Netherlands,Spain,Switzerland',
#        'Senegal,United States', 'Hong Kong,United Kingdom', 'Luxembourg',
#        'Aruba,Bolivia,Colombia,Panama,Saint Lucia,Suriname,Trinidad and Tobago,Venezuela',
#        'Santana', 'Kazakhstan,United States',
#        'France,Norway,Spain,United States',
#        'Czech Republic,France,United Kingdom',
#        'Argentina,Bolivia,Chile,Colombia,Costa Rica,Ecuador,El Salvador,Guatemala,Honduras,Mexico,Panama,Peru,United States,Uruguay,Venezuela',
#        'Argentina,Bolivia,Chile,Colombia,Costa Rica,Ecuador,El Salvador,Guatemala,Honduras,Mexico,Panama,Peru,United States,Venezuela',
#        'Chile', 'Russia', 'Taiwan,United States',
#        'Singapore,United States', 'Hong Kong,Thailand,United States',
#        'Germany,Thailand,United States', 'Germany,Japan,United States',
#        'France,Panama', 'Bolivia,Thailand,United States',
#        'France-united-states-en-united-states', 'France,Singapore',
#        'Dominica', 'The Bahamas,United States',
#        'Austria,China,Germany,Switzerland', 'Grenada,United States',
#        'France,Morocco', 'Jamaica', 'Canada,Mexico,United States',
#        'Canada,France,Mexico', 'Saint Pierre and Miquelon',
#        'Canada,Saint Pierre and Miquelon', 'Kuwait',
#        'Hungary,United Kingdom', 'Canada,Denmark,France',
#        'France,Netherlands,United States', 'France,Germany,Italy',
#        'Australia,Canada', 'Canada,France,Switzerland',
#        'Belgium,France,Switzerland', 'Spain,Francia', 'Canada,Italy',
#        'Canada,Germany', 'Austria,Canada,France', 'Brazil,Canada',
#        'Canada,Vietnam', 'Belgium,Canada', 'Benin,Canada', 'Mauritania',
#        'Canada-france', 'Canada,Singapore',
#        'Belgium,Canada,France,Switzerland',
#        'Canada,France,Saint Pierre and Miquelon',
#        'Canada,Germany,United States', 'Georgia,United States', 'Laos',
#        'Algeria,Canada,France', 'Canada,Dominican Republic,France',
#        'France,Saint Pierre and Miquelon', 'England', 'France,Martinique',
#        'Canada,France,Belgique', 'Honduras', 'Germany,Italy',
#        'France,New Zealand,United Kingdom',
#        'Austria,Belgium,France,Switzerland', 'Ireland,United Kingdom',
#        'Ghana,United States', 'Guinea,United States', 'Greece,Italy',
#        'Uruguay', 'Bolivia,Brazil,Paraguay', 'Cambodia',
#        'United States,louisiane', 'Australia,France,Germany',
#        'Mexico,Spain,Estados-unidos', 'Belgium,Norway',
#        'Poland,United States', 'Ukraine', 'American Samoa,United States',
#        'Spain,United States,Estados-unidos',
#        'Belgium,France,United Kingdom',
#        'Australia,France,Indonesia,Malaysia,New Zealand,Switzerland',
#        'Finland,France,Japan', 'France,Germany,Japan,United States',
#        'France,Netherlands', 'Ireland,United States', 'Canada,Portugal',
#        'Bolivia,Chile,Colombia,Costa Rica,Dominican Republic,Ecuador,El Salvador,Guatemala,Honduras,Mexico,Nicaragua,Panama,Peru',
#        'Germany,Saudi Arabia,United States',
#        'Germany,Taiwan,United States', 'Argentina', 'Canada,France,Italy',
#        'Brazil', 'Saint Lucia', 'France,Poland,Romania,United States',
#        'Luxembourg,United States', 'El Salvador,United States',
#        'Togo,United States', 'Germany,Spain', 'Venezuela', 'en-mexico',
#        'Chile,United States', 'Gabon,United States',
#        'Canada,France,Germany,United Kingdom,United States',
#        'France,Hong Kong,United States', 'Canada,France,Germany,Spain',
#        'France,Switzerland,United Kingdom,United States',
#        'France,Guernsey,United Kingdom', 'Canada,Italy,United States',
#        'Chile,France,United States', 'Canada,Panama',
#        'France,Hong Kong,United Kingdom', 'France,Germany,Poland',
#        'Mexico,Switzerland,United Kingdom,United States',
#        'Austria,Germany,Ireland', 'Bolivia,United Kingdom,United States',
#        'Bolivia,France,South Korea',
#        'Costa Rica,El Salvador,Guatemala,Mexico,Panama', 'Indonesia',
#        'Ghana', 'Cameroon', 'Bolivia,Ecuador', 'South Korea',
#        'New Zealand,United States', 'France,United Kingdom,U-taqa'],
#       dtype=object)

# %%
first_step =  [pays.split(",") if len(pays.split(",")) > 1 else pays for pays in unique_pays]

# Flatten the nested list
flat_list =  [[i for i in item] if isinstance(item, list) else item for item in first_step]
flat_list = [item for row in flat_list for item in (row if isinstance(row, list) else [row])]

# Flatten and get unique values
unique_values = sorted(list(set(flat_list)))

print(unique_values)
# Out:
# ['Algeria', 'Allemagne', 'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda', 'Arabie-saoudite', 'Argentina', 'Aruba', 'Australia', 'Austria', 'Bahrain', 'Barbados', 'Belgique', 'Belgium', 'Benin', 'Bermuda', 'Bolivia', 'Brazil', 'Bulgaria', 'Cambodia', 'Cameroon', 'Canada', 'Canada-france', 'Chile', 'China', 'Colombia', 'Costa Rica', 'Croatia', 'Czech Republic', "Côte d'Ivoire", 'Denmark', 'Deutschland', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'En', 'En-us', 'England', 'Estados-unidos', 'Etats-unis', 'Finland', 'France', 'France-en-canada', 'France-united-states', 'France-united-states-en-united-states', 'Francia', 'Francia-espana', 'Frankreich', 'French Polynesia', 'Gabon', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'India', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Kazakhstan', 'Kuwait', 'Laos', 'Lebanon', 'Luxembourg', 'Malaysia', 'Mark', 'Martinique', 'Mauritania', 'Mexico', 'Morocco', 'Myanmar', 'Nederland', 'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'North-carolina', 'Norway', 'Oman', 'Pakistan', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Republic-of-macedonia', 'Romania', 'Royaume-uni', 'Russia', 'Réunion', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Martin', 'Saint Pierre and Miquelon', 'Santana', 'Saudi Arabia', 'Senegal', 'Singapore', 'Sint Maarten', 'South Africa', 'South Korea', 'Spain', 'Spanien', 'Suriname', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'The Bahamas', 'Togo', 'Trinidad and Tobago', 'Turkey', 'U-taqa', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States', 'Uruguay', 'Venezuela', 'Vietnam', 'Virgin Islands of the United States', 'en-mexico', 'louisiane', 'السعودية']

# %%
#We have some errors :

errors_countries = [
"Allemagne",
"Arabie-saoudite",
"Belgique",
"Canada-france",
"Côte d'Ivoire",
"En-us",
"En",
"Estados-unidos",
"France-en-canada",
"France-united-states",
"France-united-states-en-united-states",
"Francia",
"Frankreich",
"Francia-espana",
"Deutschland",
"Mark",
"Nederland",
"North-carolina",
"Republic-of-macedonia",
"Royaume-uni",
"en-mexico",
"U-taqa", 
"Spanien",
"es:en-mexico",
"fr:louisiane",
"السعودية"
]

# %% [markdown]
# How many does it represent ?

# %%
# We retrieve all the countries names
whole_countries =  [pays.split(",") if len(pays.split(",")) > 1 else pays for pays in data.countries_en]

# Flatten the nested list
flat_list =  [[i for i in item] if isinstance(item, list) else item for item in whole_countries]

countries = [item for row in flat_list for item in (row if isinstance(row, list) else [row])]

for err in errors_countries:
    print(err, countries.count(err))
# Out:
# Allemagne 0
# Arabie-saoudite 0
# Belgique 0
# Canada-france 0
# Côte d'Ivoire 0
# En-us 0
# En 0
# Estados-unidos 0
# France-en-canada 0
# France-united-states 0
# France-united-states-en-united-states 0
# Francia 0
# Frankreich 0
# Francia-espana 0
# Deutschland 0
# Mark 0
# Nederland 0
# North-carolina 0
# Republic-of-macedonia 0
# Royaume-uni 0
# en-mexico 0
# U-taqa 0
# Spanien 0
# es:en-mexico 0
# fr:louisiane 0
# السعودية 0

# %%
"""## Pas mal de corrections à faire
Pays_a_corriger= {"Canada" : ["Québec", "Quebec", "Saint John", "Moosehead Breweries Ltd", "New Brunswick", "J3L 2H6", "La Brasserie Unibroue"], 
                  "Allemagne" : ["Deutschland", "Germany", "Duitsland", "Allemange", "Nemetorszag"], 
                  "Japon" : ["日本", "Other-日本", "Other-Japon"],
                  "Union européenne": ["Union Européenne"],
                  "Hong Kong" : ["香港"],
                  "Hongrie" : ["Magyarorszag"],
                  "Pays-Bas" : ["Niederlande", "Nederland", "Pays-bas"],
                  "Etats-Unis" : ["Îles Vierges des États-Unis", "Etats-unis","États-unis", "États-Unis", "USA", "United States of America", "California"] ,
                  "France" : ["Nouvelle-Calédonie","Cora","Puyricard", "Franciaorszag", "Saint-Pierre-et-Miquelon", "Polynésie française", "Frankrijk", 'Bourgogne-aube-nogent-sur-seine', "Frankrike","Martinique", 'Frankreich', "Guadeloupe","Paca", "Guyane", "Chambly", "La Réunion", "Marseille-6", "77-provins", "Aix-en-provence","Bouches-du-rhone",  "Bourgogne" ],
                  "Espagne" : ["Spanyolorszag", "Spanje", "Spain", "Spanien"],
                  "Trinité-et-Tobago": ["W.I.", "Carib Brewery Ltd","Champs Fleurs","Trinidad"],
                  "Suisse" : ["Zwitserland", "Schweiz", "Svajc"],
                  "Belgique": ["Belgien", "Belgie"],
                  "Portugal" : ["Portugalia"],
                  "Italie" : ["Italien", "Italy", "Torino", "Italiaans", "Italia", "italie"],
                  "Turquie": ["Other-turquie", "Turkiye"],
                  "Norvège" : ["Noorwegen"],
                  "Suède"  : ["Zweden", "Sverige"],
                  "Émirats arabes unis" : ["الإمارات-العربية-المتحدة"],
                  "République de Chine"  : ["Republique-de-chine","Republik-china", "Chine", "Kina", "République de République de Chine"],
                  "Australie" : ["Australien", "ประเทศออสเตรเลีย", "Australia"],
                  "Finlande" : ["Finand", "Finland", "Finlandee"],
                  "Brésil" : ["São Paulo Brasil"],
                  "Danemark": ["Denemarken"],
                  "Islande" :  ["Island", "Islandeee", "Islandee"],
                  "Kazakhstan" : ["Казахстан"],
                  "Azerbaïdjan" : ["Azərbaycan"],
                  "Argentine" : ["Argentina"],
                  "Royaume-Uni" : ["England","Alva","Hiifoots Village", "สหราชอาณาจักร", "Angleterre", "Royaume-uni", "Nagy-britannia", "المملكة-المتحدة", "Scotland", "Vereinigtes-konigreich"],
                  "République tchéque": ["Czech", "Tschechien", "République tchèque"],
                  "Inde" : ["भारत"],
                  "Tunisie": ["تونس"],
                  "Oman" : ["سلطنة-عمان"],
                  "Irak" : ["العراق"],
                  "" : ["Inconnu",'dairies', 'fruit-yogurts', 'stirred-yogurts', 'whole-milk-yogurts', 'yogurts'],
                  "Pologne"  : ["Szczecin"], 
                  "Thaïlande" : ["ประเทศไทย"],
                  "Arabie Saoudite" : ["السعودية", "Arabie saoudite"]
                 }
"""

# %%
# We will search tags "xx:"" and eliminate them
#data["countries_en"] = data["countries_en"].str.replace("..:","", regex= True)

# %%
to_correct = {
"Germany" : ["Allemagne", "Deutschland"],
"Saudi Arabia" : ["Arabie-saoudite", "السعودية"],
"Belgium" : ["Belgique"],
"England" : ["En"],
"France" : ["Francia", "Frankreich"],
"Guernesey" : ["Guernsey"],
"United Kingdom" : ["Royaume-uni"],
"" : ["U-taqa", "Mark"],
"Spain" : ["Spanien"],
"Ivory Coast" : ["Côte d'Ivoire"],
"United States" : ["Estados-unidos", "North-carolina", "fr:louisiane", "En-us"],
"France,Canada" : ["France-en-canada", "Canada-france"],
"France,United States" : ["France-united-states-en-united-states", "France-united-states"],
"France,Spain" : ["Francia-espana"],
"Netherlands" : ["Nederland"],
"Republic of North Macedonia" : ["Republic-of-macedonia"],
"Mexico" : ["es:en-mexico"]
}

# %%
# Correction des erreurs 
for key in to_correct:
    for k in to_correct.get(key) :
        print(k)
        data["countries_en"] = data["countries_en"].apply(lambda x : key if x == k else x if len(x.split(",")) == 1 
                                else ",".join([key if p == k else p for p in x.split(",")]))
# Out:
# Allemagne
# Deutschland
# Arabie-saoudite
# السعودية
# Belgique
# En
# Francia
# Frankreich
# Guernsey
# Royaume-uni
# U-taqa
# Mark
# Spanien
# Côte d'Ivoire
# Estados-unidos
# North-carolina
# louisiane
# En-us
# France-en-canada
# Canada-france
# France-united-states-en-united-states
# France-united-states
# Francia-espana
# Nederland
# Republic-of-macedonia
# en-mexico

# %%
raw_index = data[data["countries_en"]  == ""].index
print("We going from %d rows" %data.shape[0], end = " ")
data = data.loc[~data.index.isin(raw_index)]
print("to %d rows after clean-up" %data.shape[0])
# Out:
# We going from 155589 rows to 155588 rows after clean-up

# %% [markdown]
# ### <a name = "T2C9">i. Distribution of products by countries</a>

# %%
count_countries
# Out:
# [['', 1],
#  ['Argentina', 10],
#  ['Vietnam', 3],
#  ['Ireland', 39],
#  ['Grenada', 1],
#  ['Panama', 49],
#  ['Hong Kong', 27],
#  ['Spain', 446],
#  ['Dominica', 1],
#  ['Antigua and Barbuda', 1],
#  ['Réunion', 2],
#  ['Cambodia', 4],
#  ['United Kingdom', 1639],
#  ['Norway', 14],
#  ['Indonesia', 5],
#  ['Nicaragua', 8],
#  ['Ecuador', 8],
#  ['Oman', 1],
#  ['Guam', 1],
#  ['Kuwait', 5],
#  ['Santana', 1],
#  ['Gabon', 1],
#  ['Ukraine', 1],
#  ['Pakistan', 4],
#  ['Egypt', 3],
#  ['Andorra', 2],
#  ['Denmark', 5],
#  ['Morocco', 4],
#  ['Turkey', 1],
#  ['New Caledonia', 6],
#  ['Thailand', 36],
#  ['Aruba', 1],
#  ['Taiwan', 6],
#  ['China', 5],
#  ['Barbados', 4],
#  ['Lebanon', 6],
#  ['India', 5],
#  ['Costa Rica', 33],
#  ['Martinique', 5],
#  ['Trinidad and Tobago', 13],
#  ['Switzerland', 136],
#  ['Qatar', 2],
#  ['Sint Maarten', 1],
#  ['Anguilla', 2],
#  ['Venezuela', 5],
#  ['El Salvador', 16],
#  ['Austria', 23],
#  ['Philippines', 4],
#  ['England', 5],
#  ['Finland', 2],
#  ['Suriname', 1],
#  ['Honduras', 10],
#  ['Australia', 40],
#  ['Bahrain', 4],
#  ['Malaysia', 5],
#  ['Canada', 4873],
#  ['Haiti', 3],
#  ['Saudi Arabia', 20],
#  ['Mexico', 338],
#  ['Bermuda', 3],
#  ['Myanmar', 1],
#  ['New Zealand', 6],
#  ['Israel', 3],
#  ['American Samoa', 1],
#  ['Greece', 4],
#  ['Senegal', 2],
#  ['South Korea', 3],
#  ['Russia', 3],
#  ['Bulgaria', 2],
#  ['South Africa', 4],
#  ['Cameroon', 1],
#  ['Hungary', 3],
#  ['Georgia', 1],
#  ['Japan', 11],
#  ['Guyana', 1],
#  ['Singapore', 35],
#  ['French Polynesia', 75],
#  ['Saint Pierre and Miquelon', 12],
#  ['Czech Republic', 15],
#  ['Ivory Coast', 1],
#  ['Niger', 1],
#  ['Peru', 11],
#  ['Colombia', 21],
#  ['Romania', 11],
#  ['Laos', 1],
#  ['Kazakhstan', 1],
#  ['Jersey', 8],
#  ['Italy', 82],
#  ['Republic of North Macedonia', 1],
#  ['Belgium', 91],
#  ['Etats-unis', 2],
#  ['Algeria', 1],
#  ['Ghana', 2],
#  ['Uruguay', 6],
#  ['Mauritania', 1],
#  ['Saint Lucia', 3],
#  ['Sweden', 15],
#  ['Benin', 1],
#  ['Luxembourg', 4],
#  ['Netherlands', 38],
#  ['Brazil', 9],
#  ['Togo', 1],
#  ['Jamaica', 8],
#  ['Saint Kitts and Nevis', 2],
#  ['Virgin Islands of the United States', 2],
#  ['Portugal', 5],
#  ['Saint Martin', 2],
#  ['Croatia', 1],
#  ['Guinea', 1],
#  ['Paraguay', 7],
#  ['Germany', 454],
#  ['Chile', 7],
#  ['France', 4504],
#  ['Poland', 10],
#  ['Dominican Republic', 12],
#  ['Angola', 1],
#  ['United Arab Emirates', 12],
#  ['The Bahamas', 3],
#  ['Guernesey', 1],
#  ['Guatemala', 14],
#  ['United States', 146599],
#  ['Puerto Rico', 60],
#  ['Bolivia', 229],
#  ['Guadeloupe', 7]]

# %%
def distributionPays(df, threshold = 100):

    """
    Calculate the occurence of each country
    To not show unimportant countries, we set a threshold (default = 100)
    """

    whole_countries =  [pays.split(",") if len(pays.split(",")) > 1 else pays for pays in data.countries_en]
    
    # Flatten the nested list
    flat_list =  [[i for i in item] if isinstance(item, list) else item for item in whole_countries]
    
    countries = [item for row in flat_list for item in (row if isinstance(row, list) else [row])]
    
    countries_unique = set(countries)
    
    count_countries = [[i, countries.count(i)] for i in countries_unique]


    
    #On compte le nombre de produits par pays
    count_pays = df["countries_en"].value_counts().reset_index()
    count_pays["pourcent"] = count_pays["countries_en"]/count_pays["countries_en"].sum()*100
    
    # On affiche un tableau du cocmptage
    display(count_pays[count_pays.countries_fr > nombre])
    
    longueur = count_pays[count_pays.countries_fr > nombre].shape[0]
    
    #On affiche ce comptage par un barplot
    plt.figure(figsize=(12,longueur*0.7))
    
    sns.barplot(data = count_pays[count_pays.countries_fr > nombre], y = "index", x= "countries_en", color = "red", orient = "h")    
    plt.title("Nombre de produits par pays", fontsize = 20)
    plt.xlabel("Nombre de produits", fontsize=18)
    plt.ylabel("Pays", fontsize=18)
    
    plt.show()

# %%
distributionPays(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\Desktop\Data scientist formation\[Projets]\Projet NutritionApp\env\Lib\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[402], line 1
# ----> 1 distributionPays(data)
#
# Cell In[401], line 7, in distributionPays(df, nombre)
#       2 def distributionPays(df, nombre = 100):
#       3     # nombre = on affiche les pays avec au moins cette quantitée de produits. Par défaut 100.
#       4
#       5     #On compte le nombre de produits par pays
#       6     count_pays = df["countries_en"].value_counts().reset_index()
# ----> 7     count_pays["pourcent"] = count_pays["countries_en"]/count_pays["countries_en"].sum()*100
#       9     # On affiche un tableau du cocmptage
#      10     display(count_pays[count_pays.countries_fr > nombre])
#
# File ~\Desktop\Data scientist formation\[Projets]\Projet NutritionApp\env\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\Desktop\Data scientist formation\[Projets]\Projet NutritionApp\env\Lib\site-packages\pandas\core\arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File ~\Desktop\Data scientist formation\[Projets]\Projet NutritionApp\env\Lib\site-packages\pandas\core\series.py:5815, in Series._arith_method(self, other, op)
#    5813 def _arith_method(self, other, op):
#    5814     self, other = self._align_for_op(other)
# -> 5815     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\Desktop\Data scientist formation\[Projets]\Projet NutritionApp\env\Lib\site-packages\pandas\core\base.py:1381, in IndexOpsMixin._arith_method(self, other, op)
#    1378     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1380 with np.errstate(all="ignore"):
# -> 1381     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383 return self._construct_result(result, name=res_name)
#
# File ~\Desktop\Data scientist formation\[Projets]\Projet NutritionApp\env\Lib\site-packages\pandas\core\ops\array_ops.py:285, in arithmetic_op(left, right, op)
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     283     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 285     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     287 return res_values
#
# File ~\Desktop\Data scientist formation\[Projets]\Projet NutritionApp\env\Lib\site-packages\pandas\core\ops\array_ops.py:229, in _na_arithmetic_op(left, right, op, is_cmp)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
# --> 229         result = _masked_arith_op(left, right, op)
#     230     else:
#     231         raise
#
# File ~\Desktop\Data scientist formation\[Projets]\Projet NutritionApp\env\Lib\site-packages\pandas\core\ops\array_ops.py:184, in _masked_arith_op(x, y, op)
#     181         mask = np.where(y == 1, False, mask)
#     183     if mask.any():
# --> 184         result[mask] = op(xrav[mask], y)
#     186 np.putmask(result, ~mask, np.nan)
#     187 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# Seulement 16 pays ont plus de 100 produits entrés sur la database.
#
# La majorité des produits entrés proviennent (62%) des Etats-Unis. Le second pays représenté est la France, avec moitié moins de produits (27%)

# %%
distributionPays(data, 1000)
# Out:
#          index  countries_fr   pourcent
# 0   Etats-Unis        157739  62.726517
# 1       France         66162  26.309992
# 2       Suisse         10212   4.060906
# 3    Allemagne          5305   2.109587
# 4      Espagne          3271   1.300746
# 5  Royaume-Uni          2344   0.932115
# 6     Belgique          1393   0.553941

# %%
# On appel notre fonction afin d'éliminer les features avec 100 % de valeurs manquantes
data = eliminationFeature(data, 100, "==")
# Out:
# On passe de 146 à 141 features
# Avec cette liste de features éliminées :
# 27                              cities
# 36                        allergens_fr
# 70                   behenic-acid_100g
# 82    dihomo-gamma-linolenic-acid_100g
# 85                   gondoic-acid_100g
# Name: Features, dtype: object

# %% [markdown]
# ***
# # <a name = "T3"> Valeurs aberrantes et manquantes </a>

# %% [markdown]
# ### <a name = "T3C1">a. Observation des valeurs nutritives </a>

# %% [markdown]
# On avait déjà observé toute à l'heure des valeurs aberrantes pour les données /100g. On va les analyser plus en détail.

# %%
# on créé une liste des noms comprenant les features /100g.
poids_cols = [col for col in data.columns if "100g" in col]
display(poids_cols)
# Out:
# ['energy_100g',
#  'energy-from-fat_100g',
#  'fat_100g',
#  'saturated-fat_100g',
#  'caprylic-acid_100g',
#  'capric-acid_100g',
#  'lauric-acid_100g',
#  'myristic-acid_100g',
#  'palmitic-acid_100g',
#  'stearic-acid_100g',
#  'arachidic-acid_100g',
#  'montanic-acid_100g',
#  'monounsaturated-fat_100g',
#  'polyunsaturated-fat_100g',
#  'omega-3-fat_100g',
#  'alpha-linolenic-acid_100g',
#  'eicosapentaenoic-acid_100g',
#  'docosahexaenoic-acid_100g',
#  'omega-6-fat_100g',
#  'linoleic-acid_100g',
#  'arachidonic-acid_100g',
#  'gamma-linolenic-acid_100g',
#  'omega-9-fat_100g',
#  'oleic-acid_100g',
#  'trans-fat_100g',
#  'cholesterol_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'sucrose_100g',
#  'glucose_100g',
#  'fructose_100g',
#  'lactose_100g',
#  'maltose_100g',
#  'maltodextrins_100g',
#  'starch_100g',
#  'polyols_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'casein_100g',
#  'serum-proteins_100g',
#  'nucleotides_100g',
#  'salt_100g',
#  'sodium_100g',
#  'alcohol_100g',
#  'vitamin-a_100g',
#  'beta-carotene_100g',
#  'vitamin-d_100g',
#  'vitamin-e_100g',
#  'vitamin-k_100g',
#  'vitamin-c_100g',
#  'vitamin-b1_100g',
#  'vitamin-b2_100g',
#  'vitamin-pp_100g',
#  'vitamin-b6_100g',
#  'vitamin-b9_100g',
#  'folates_100g',
#  'vitamin-b12_100g',
#  'biotin_100g',
#  'pantothenic-acid_100g',
#  'silica_100g',
#  'bicarbonate_100g',
#  'potassium_100g',
#  'chloride_100g',
#  'calcium_100g',
#  'phosphorus_100g',
#  'iron_100g',
#  'magnesium_100g',
#  'zinc_100g',
#  'copper_100g',
#  'manganese_100g',
#  'fluoride_100g',
#  'selenium_100g',
#  'chromium_100g',
#  'molybdenum_100g',
#  'iodine_100g',
#  'caffeine_100g',
#  'taurine_100g',
#  'ph_100g',
#  'fruits-vegetables-nuts_100g',
#  'collagen-meat-protein-ratio_100g',
#  'cocoa_100g',
#  'carbon-footprint_100g',
#  'nutrition-score-fr_100g',
#  'nutrition-score-uk_100g']

# %%
# On élimine de la liste l'énergie, le nutriscore et 'carbon-footprint_100g'
remove_list = ['energy_100g','energy-from-fat_100g','nutrition-score-fr_100g','nutrition-score-uk_100g', 'carbon-footprint_100g']

poids_cols = [i for i in poids_cols if i not in remove_list]

# %%
with pd.option_context('display.max_columns', None):
    display(data[poids_cols].describe())
# Out:
#             fat_100g  saturated-fat_100g  caprylic-acid_100g  \
# count  229815.000000       218853.000000                 1.0
# mean       12.627786            5.117767                 7.4
# std        17.011675            7.969273                 NaN
# min         0.000000            0.000000                 7.4
# 25%         0.000000            0.000000                 7.4
# 50%         5.310000            1.800000                 7.4
# 75%        20.000000            7.140000                 7.4
# max       714.290000          550.000000                 7.4
#
#        capric-acid_100g  lauric-acid_100g  myristic-acid_100g  \
# count          2.000000          4.000000                 1.0
# mean           6.040000         36.136182                18.9
# std            0.226274         24.101433                 NaN
# min            5.880000          0.044730                18.9
# 25%            5.960000         34.661183                18.9
# 50%            6.040000         47.600000                18.9
# 75%            6.120000         49.075000                18.9
# max            6.200000         49.300000                18.9
#
#        palmitic-acid_100g  stearic-acid_100g  arachidic-acid_100g  \
# count                 1.0                1.0                1.000
# mean                  8.1                3.0                0.064
# std                   NaN                NaN                  NaN
# min                   8.1                3.0                0.064
# 25%                   8.1                3.0                0.064
# 50%                   8.1                3.0                0.064
# 75%                   8.1                3.0                0.064
# max                   8.1                3.0                0.064
#
#        montanic-acid_100g  monounsaturated-fat_100g  polyunsaturated-fat_100g  \
# count                 1.0              20846.000000              20861.000000
# mean                 61.0                  9.386819                  5.729660
# std                   NaN                 15.567137                  9.813409
# min                  61.0                  0.000000                  0.000000
# 25%                  61.0                  0.000000                  0.000000
# 50%                  61.0                  3.700000                  2.000000
# 75%                  61.0                 10.000000                  7.000000
# max                  61.0                557.140000                 98.000000
#
#        omega-3-fat_100g  alpha-linolenic-acid_100g  \
# count        851.000000                 189.000000
# mean           3.179714                   2.559989
# std            5.470238                   8.649802
# min            0.000000                   0.000000
# 25%            0.600000                   0.071000
# 50%            1.800000                   0.120000
# 75%            3.200000                   0.700000
# max           60.000000                  75.000000
#
#        eicosapentaenoic-acid_100g  docosahexaenoic-acid_100g  \
# count                   37.000000                  56.000000
# mean                     3.383757                   0.748589
# std                     14.090175                   1.625047
# min                      0.050000                   0.041000
# 25%                      0.200000                   0.126000
# 50%                      0.600000                   0.497000
# 75%                      1.020000                   0.900000
# max                     85.000000                  12.000000
#
#        omega-6-fat_100g  linoleic-acid_100g  arachidonic-acid_100g  \
# count        195.000000          149.000000               8.000000
# mean          16.151995            3.742745               0.057000
# std           17.499896            6.321809               0.025534
# min            0.050000            0.090000               0.007000
# 25%            2.075000            0.437000               0.046250
# 50%            9.100000            0.647000               0.061000
# 75%           23.000000            3.600000               0.068500
# max           71.000000           25.000000               0.090000
#
#        gamma-linolenic-acid_100g  omega-9-fat_100g  oleic-acid_100g  \
ruits-vegetables-nuts_100g  collagen-meat-protein-ratio_100g  \
# count                  3098.000000                        164.000000
# mean                     31.785207                         15.396341
# std                      32.069868                          3.773688
# min                       0.000000                          8.000000
# 25%                       0.000000                         12.000000
# 50%                      24.000000                         15.000000
# 75%                      51.425000                         15.000000
# max                     100.000000                         25.000000
#
#         cocoa_100g
# count  1121.000000
# mean     50.573595
# std      19.161187
# min       6.000000
# 25%      32.000000
# 50%      50.000000
# 75%      70.000000
# max     100.000000

# %% [markdown]
# - On observe:
#     - Des valeurs négatives
#         - Erreurs de saisie (- au lieu de +)
#     - Des valeurs > 100g/100g
#     - Des valeurs > 100 à 1000 fois supérieurs à la médiane
#         - Pour les deux catégories, une erreur entre mg et g
#
# - Résolution:
#      - Valeurs négatives, passer en positives
#      - Diviser par 1000 quand on voit que la valeur est trop éloignée de la médiane (valeur aberrante)

# %%
# Fonction permettant de tester si la modification impacte significativement la distribution de nos échantillons ou non
# Retourne True si la modification ne change pas significativement les données
# Retourne False si la modification ne change pas significativement les données
def resultcorrection_ttest(old_df, new_df, feature, paired = False):
    # Si les dataframes à comparer sont différents, on fait le test
    if old_df[feature].equals(new_df[feature]) == False:
       
       # Si on a plus de 1 valeur, on fait le test
        if(old_df[feature].count() > 1):
            
            if paired == True:
                # On exclu les valeurs NaN
                result_test = stats.ttest_rel(old_df[feature], new_df[feature], nan_policy = "omit")
                    
            else :
                
                if old_df[feature].notnull().sum() > new_df[feature].notnull().sum():
                    condition = old_df.index.isin(new_df.index)
                    result_test = stats.ttest_ind(old_df[feature][condition], new_df[feature], nan_policy = "omit")
                    
                if old_df[feature].notnull().sum() < new_df[feature].notnull().sum():
                    condition = new_df.index.isin(old_df.index)
                    result_test = stats.ttest_ind(old_df[feature], new_df[feature][condition], nan_policy = "omit")
                    
                if old_df[feature].notnull().sum() == new_df[feature].notnull().sum():
                    result_test = stats.ttest_ind(old_df[feature], new_df[feature], nan_policy = "omit")

        if result_test[1] <= 0.05:
            print(feature,": la modification change drastiquement les données, p_value:", result_test[1])
            graphique_boxplot(old_df[feature], new_df[feature], feature)
            standard_variation(old_df[feature], new_df[feature])
            return False

        else:
            return True
        

def graphique_boxplot(old_df, new_df, feature):
    pdFig = pd.DataFrame(columns = ["Avant", "Après"])
    pdFig["Avant"] = old_df
    pdFig["Après"] = new_df
    
    plt.figure(figsize=(5,5))
    plt.title("Distribution de la feature : "+str(feature), fontsize = 14)
    plt.ylabel("g/100g", fontsize=14)
    sns.boxplot(data = pdFig)
    plt.show()

def standard_variation(old_df, new_df):
    
    sv = lambda x: np.std(x, ddof=1) / np.mean(x) * 100 

    sv_old = sv(old_df)
    sv_new = sv(new_df)

    print("Calcul du coefficient de variation :")
    print("Avant traitement = ", sv_old)
    print("Après traitement = ", sv_new)

# %% [markdown]
# #### <a name = "T3C2">2. Valeurs négatives</a>

# %% [markdown]
# Etant donné que les valeurs négatives sont potentiellement issues d'une mauvaise entrée, on va les corriger en les mettant en positif.
#
# La modification ne devrait pas modifier la distribution de nos échantillons (test stats)

# %%
# Fonction pour corriger si la valeur entrée est négative
def corr_absolu(df, feature):
   
    for col in feature:
        # On regarde si une modification doit être réalisée
        
        if df.loc[df[col] < 0, col].count() > 0:
            
            #Test statistique de la modification
            mask = copy.deepcopy(df)
            mask.loc[df[col] < 0, col] = abs(mask.loc[df[col] < 0, col])
            
            #if resultcorrection_paired(df, mask, col) == True:
            if resultcorrection_ttest(df, mask, col, True) == True:
                df.loc[df[col] < 0, col] =  abs(df.loc[df[col] < 0, col])

    return df

# %%
data = corr_absolu(data, poids_cols)

with pd.option_context('display.max_columns', None):
    display(data[poids_cols].describe())
# Out:
#             fat_100g  saturated-fat_100g  caprylic-acid_100g  \
# count  229815.000000       218853.000000                 1.0
# mean       12.627786            5.117767                 7.4
# std        17.011675            7.969273                 NaN
# min         0.000000            0.000000                 7.4
# 25%         0.000000            0.000000                 7.4
# 50%         5.310000            1.800000                 7.4
# 75%        20.000000            7.140000                 7.4
# max       714.290000          550.000000                 7.4
#
#        capric-acid_100g  lauric-acid_100g  myristic-acid_100g  \
# count          2.000000          4.000000                 1.0
# mean           6.040000         36.136182                18.9
# std            0.226274         24.101433                 NaN
# min            5.880000          0.044730                18.9
# 25%            5.960000         34.661183                18.9
# 50%            6.040000         47.600000                18.9
# 75%            6.120000         49.075000                18.9
# max            6.200000         49.300000                18.9
#
#        palmitic-acid_100g  stearic-acid_100g  arachidic-acid_100g  \
# count                 1.0                1.0                1.000
# mean                  8.1                3.0                0.064
# std                   NaN                NaN                  NaN
# min                   8.1                3.0                0.064
# 25%                   8.1                3.0                0.064
# 50%                   8.1                3.0                0.064
# 75%                   8.1                3.0                0.064
# max                   8.1                3.0                0.064
#
#        montanic-acid_100g  monounsaturated-fat_100g  polyunsaturated-fat_100g  \
# count                 1.0              20846.000000              20861.000000
# mean                 61.0                  9.386819                  5.729660
# std                   NaN                 15.567137                  9.813409
# min                  61.0                  0.000000                  0.000000
# 25%                  61.0                  0.000000                  0.000000
# 50%                  61.0                  3.700000                  2.000000
# 75%                  61.0                 10.000000                  7.000000
# max                  61.0                557.140000                 98.000000
#
#        omega-3-fat_100g  alpha-linolenic-acid_100g  \
# count        851.000000                 189.000000
# mean           3.179714                   2.559989
# std            5.470238                   8.649802
# min            0.000000                   0.000000
# 25%            0.600000                   0.071000
# 50%            1.800000                   0.120000
# 75%            3.200000                   0.700000
# max           60.000000                  75.000000
#
#        eicosapentaenoic-acid_100g  docosahexaenoic-acid_100g  \
# count                   37.000000                  56.000000
# mean                     3.383757                   0.748589
# std                     14.090175                   1.625047
# min                      0.050000                   0.041000
# 25%                      0.200000                   0.126000
# 50%                      0.600000                   0.497000
# 75%                      1.020000                   0.900000
# max                     85.000000                  12.000000
#
#        omega-6-fat_100g  linoleic-acid_100g  arachidonic-acid_100g  \
# count        195.000000          149.000000               8.000000
# mean          16.151995            3.742745               0.057000
# std           17.499896            6.321809               0.025534
# min            0.050000            0.090000               0.007000
# 25%            2.075000            0.437000               0.046250
# 50%            9.100000            0.647000               0.061000
# 75%           23.000000            3.600000               0.068500
# max           71.000000           25.000000               0.090000
#
#        gamma-linolenic-acid_100g  omega-9-fat_100g  oleic-acid_100g  \
ruits-vegetables-nuts_100g  collagen-meat-protein-ratio_100g  \
# count                  3098.000000                        164.000000
# mean                     31.785207                         15.396341
# std                      32.069868                          3.773688
# min                       0.000000                          8.000000
# 25%                       0.000000                         12.000000
# 50%                      24.000000                         15.000000
# 75%                      51.425000                         15.000000
# max                     100.000000                         25.000000
#
#         cocoa_100g
# count  1121.000000
# mean     50.573595
# std      19.161187
# min       6.000000
# 25%      32.000000
# 50%      50.000000
# 75%      70.000000
# max     100.000000

# %% [markdown]
# **Il n'y a plus de valeurs négatives**

# %% [markdown]
# ##### <a name = "T3C3">3. Valeurs à la mauvaise unité</a>

# %% [markdown]
# On repère ces valeurs car elles sont soient :
# - supérieure à 100/100g
# - 100 à 1000 fois supérieures à la médiane

# %%
# On élimine de la liste le sodium et le salt, car cas particuliers
remove_list = ['salt_100g','sodium_100g']
poids_cols = [i for i in poids_cols if i not in remove_list]

# %%
with pd.option_context('display.max_columns', None):
    display(data[poids_cols].describe())
# Out:
#             fat_100g  saturated-fat_100g  caprylic-acid_100g  \
# count  229815.000000       218853.000000                 1.0
# mean       12.627786            5.117767                 7.4
# std        17.011675            7.969273                 NaN
# min         0.000000            0.000000                 7.4
# 25%         0.000000            0.000000                 7.4
# 50%         5.310000            1.800000                 7.4
# 75%        20.000000            7.140000                 7.4
# max       714.290000          550.000000                 7.4
#
#        capric-acid_100g  lauric-acid_100g  myristic-acid_100g  \
# count          2.000000          4.000000                 1.0
# mean           6.040000         36.136182                18.9
# std            0.226274         24.101433                 NaN
# min            5.880000          0.044730                18.9
# 25%            5.960000         34.661183                18.9
# 50%            6.040000         47.600000                18.9
# 75%            6.120000         49.075000                18.9
# max            6.200000         49.300000                18.9
#
#        palmitic-acid_100g  stearic-acid_100g  arachidic-acid_100g  \
# count                 1.0                1.0                1.000
# mean                  8.1                3.0                0.064
# std                   NaN                NaN                  NaN
# min                   8.1                3.0                0.064
# 25%                   8.1                3.0                0.064
# 50%                   8.1                3.0                0.064
# 75%                   8.1                3.0                0.064
# max                   8.1                3.0                0.064
#
#        montanic-acid_100g  monounsaturated-fat_100g  polyunsaturated-fat_100g  \
# count                 1.0              20846.000000              20861.000000
# mean                 61.0                  9.386819                  5.729660
# std                   NaN                 15.567137                  9.813409
# min                  61.0                  0.000000                  0.000000
# 25%                  61.0                  0.000000                  0.000000
# 50%                  61.0                  3.700000                  2.000000
# 75%                  61.0                 10.000000                  7.000000
# max                  61.0                557.140000                 98.000000
#
#        omega-3-fat_100g  alpha-linolenic-acid_100g  \
# count        851.000000                 189.000000
# mean           3.179714                   2.559989
# std            5.470238                   8.649802
# min            0.000000                   0.000000
# 25%            0.600000                   0.071000
# 50%            1.800000                   0.120000
# 75%            3.200000                   0.700000
# max           60.000000                  75.000000
#
#        eicosapentaenoic-acid_100g  docosahexaenoic-acid_100g  \
# count                   37.000000                  56.000000
# mean                     3.383757                   0.748589
# std                     14.090175                   1.625047
# min                      0.050000                   0.041000
# 25%                      0.200000                   0.126000
# 50%                      0.600000                   0.497000
# 75%                      1.020000                   0.900000
# max                     85.000000                  12.000000
#
#        omega-6-fat_100g  linoleic-acid_100g  arachidonic-acid_100g  \
# count        195.000000          149.000000               8.000000
# mean          16.151995            3.742745               0.057000
# std           17.499896            6.321809               0.025534
# min            0.050000            0.090000               0.007000
# 25%            2.075000            0.437000               0.046250
# 50%            9.100000            0.647000               0.061000
# 75%           23.000000            3.600000               0.068500
# max           71.000000           25.000000               0.090000
#
#        gamma-linolenic-acid_100g  omega-9-fat_100g  oleic-acid_100g  \
def ajustement(df, feature):
    df.loc[(df[feature] > 100) & (df[feature] <= 110), feature] = 100

    #On élimine quand c'est trop extrêmes
    index_elim = df[df[feature] > 110].index
    
    if(len(index_elim) > 0):
        df = df[~df.index.isin(index_elim)]
        print(len(index_elim),"lignes supprimées")
        
    return df

# %%
## Version 1

def mauvaiseUnite_corr(df) :
    
    remove_list = ['energy_100g','energy-from-fat_100g','nutrition-score-fr_100g','nutrition-score-uk_100g','carbon-footprint_100g']
    
    poids_cols = [col for col in df.columns if ("100g" in col) & (col not in remove_list)]
    
    with pd.option_context('display.max_columns', None):
        print("Avant correction :")
        display(df[poids_cols].describe())
    
    mask = copy.deepcopy(df)
    
    # Si on trouve une colonne où la valeur est >1000, on divise toutes les colonnes par 1000
    liste_valeurs_1000 = [y for col in poids_cols for y in df[df[col] > 1000].index]   
    # On garde l'indice quand une valeur excédentaire est retrouvée dans plus de 1 colonne 
    liste_valeurs_1000 = list(set([i for i in liste_valeurs_1000 if liste_valeurs_1000.count(i) >= 1])) 
    # On divise par 1000
    df.loc[df.index.isin(liste_valeurs_1000), poids_cols] = df.loc[df.index.isin(liste_valeurs_1000), poids_cols] / 1000
    
    # Si on retrouve une colonne où la valeur est > 100 et qu'une seconde l'est, on divise par 1000     
    # On récupère les indices où on retrouve une valeur > 100
    liste_valeurs_100 = [y for col in poids_cols for y in df[df[col] > 100].index]
    # On garde l'indice quand une valeur excédentaire est retrouvée dans plus de 2 colonnes 
    liste_valeurs_100 = list(set([i for i in liste_valeurs_100 if liste_valeurs_100.count(i) >= 2]))
    # On divise par 1000
    df.loc[df.index.isin(liste_valeurs_100), poids_cols] = df.loc[df.index.isin(liste_valeurs_100), poids_cols] / 1000
    
    # Test statistique
    for col in poids_cols:
        resultcorrection_ttest(mask, df, col, False)
    
    nb_ligne = df.shape[0]
    remove_list = ['energy_100g','energy-from-fat_100g','nutrition-score-fr_100g','nutrition-score-uk_100g','sodium_100g', "salt_100g",'carbon-footprint_100g']
    
    poids_cols = [col for col in df.columns if ("100g" in col) & (col not in remove_list)]
    for col in poids_cols :
        mask = copy.deepcopy(df)
        # Trans fat est à part. Il y a des aliments riches en trans fat
        if col != "trans-fat_100g":
            #Quand la moyenne/median est inférieur à 1. On cherche les outliers qui sont 50 fois supérieur.
            if df[col].median() > 0:
                med = df[col].median()
            else :
                med = df[col].mean()

            condition = (med < 1) & (df[col] > med * 50)
            
            #Tant qu'on est pas satisfait de la nouvelle valeur, on continue (le cas des valeurs qui sont 10^6 à leur vrai valeurs).
            while df.loc[condition, col].shape[0] > 0:
                condition = (med < 1) & (df[col] > med * 50)
                if df[col].median() > 0:
                    med = df[col].median()
                else :
                    med = df[col].mean()

                df.loc[condition, col] = (
                df.loc[condition, col].apply(lambda x: (x/100) 
                    if (abs(med - x / 100) < abs(med - x / 1000)) else (x/1000))) 
                
        
        # Test statistique
        resultcorrection_ttest(mask, df, col, False)
        
        # Si la valeur est comprise entre 100 et 110, elle est corrigée encore aberrante, elle est éliminée
        df = ajustement(df, col)    
    
    print("On passe de %d" %nb_ligne, end = " ")
    print("à %d lignes" %df.shape[0], end = " ")
    print("(- %d)" %(nb_ligne - df.shape[0]))
        
    with pd.option_context('display.max_columns', None):
        print("Après correction :")
        display(df[poids_cols].describe())
        
    return df

# %%
# Pour garder en mémoire
carboAvant = copy.deepcopy(data["carbohydrates_100g"])

# %%
# On corrige les valeurs aberantes avec notre fonction
data = mauvaiseUnite_corr(data)
# Out:
# Avant correction :
#             fat_100g  saturated-fat_100g  caprylic-acid_100g  \
# count  229815.000000       218853.000000                 1.0
# mean       12.627786            5.117767                 7.4
# std        17.011675            7.969273                 NaN
# min         0.000000            0.000000                 7.4
# 25%         0.000000            0.000000                 7.4
# 50%         5.310000            1.800000                 7.4
# 75%        20.000000            7.140000                 7.4
# max       714.290000          550.000000                 7.4
#
#        capric-acid_100g  lauric-acid_100g  myristic-acid_100g  \
# count          2.000000          4.000000                 1.0
# mean           6.040000         36.136182                18.9
# std            0.226274         24.101433                 NaN
# min            5.880000          0.044730                18.9
# 25%            5.960000         34.661183                18.9
# 50%            6.040000         47.600000                18.9
# 75%            6.120000         49.075000                18.9
# max            6.200000         49.300000                18.9
#
#        palmitic-acid_100g  stearic-acid_100g  arachidic-acid_100g  \
# count                 1.0                1.0                1.000
# mean                  8.1                3.0                0.064
# std                   NaN                NaN                  NaN
# min                   8.1                3.0                0.064
# 25%                   8.1                3.0                0.064
# 50%                   8.1                3.0                0.064
# 75%                   8.1                3.0                0.064
# max                   8.1                3.0                0.064
#
#        montanic-acid_100g  monounsaturated-fat_100g  polyunsaturated-fat_100g  \
# count                 1.0              20846.000000              20861.000000
# mean                 61.0                  9.386819                  5.729660
# std                   NaN                 15.567137                  9.813409
# min                  61.0                  0.000000                  0.000000
# 25%                  61.0                  0.000000                  0.000000
# 50%                  61.0                  3.700000                  2.000000
# 75%                  61.0                 10.000000                  7.000000
# max                  61.0                557.140000                 98.000000
#
#        omega-3-fat_100g  alpha-linolenic-acid_100g  \
# count        851.000000                 189.000000
# mean           3.179714                   2.559989
# std            5.470238                   8.649802
# min            0.000000                   0.000000
# 25%            0.600000                   0.071000
# 50%            1.800000                   0.120000
# 75%            3.200000                   0.700000
# max           60.000000                  75.000000
#
#        eicosapentaenoic-acid_100g  docosahexaenoic-acid_100g  \
# count                   37.000000                  56.000000
# mean                     3.383757                   0.748589
# std                     14.090175                   1.625047
# min                      0.050000                   0.041000
# 25%                      0.200000                   0.126000
# 50%                      0.600000                   0.497000
# 75%                      1.020000                   0.900000
# max                     85.000000                  12.000000
#
#        omega-6-fat_100g  linoleic-acid_100g  arachidonic-acid_100g  \
# count        195.000000          149.000000               8.000000
# mean          16.151995            3.742745               0.057000
# std           17.499896            6.321809               0.025534
# min            0.050000            0.090000               0.007000
# 25%            2.075000            0.437000               0.046250
# 50%            9.100000            0.647000               0.061000
# 75%           23.000000            3.600000               0.068500
# max           71.000000           25.000000               0.090000
#
#        gamma-linolenic-acid_100g  omega-9-fat_100g  oleic-acid_100g  \
ruits-vegetables-nuts_100g  collagen-meat-protein-ratio_100g  \
# count                  3098.000000                        164.000000
# mean                     31.785207                         15.396341
# std                      32.069868                          3.773688
# min                       0.000000                          8.000000
# 25%                       0.000000                         12.000000
# 50%                      24.000000                         15.000000
# 75%                      51.425000                         15.000000
# max                     100.000000                         25.000000
#
#         cocoa_100g
# count  1121.000000
# mean     50.573595
# std      19.161187
# min       6.000000
# 25%      32.000000
# 50%      50.000000
# 75%      70.000000
# max     100.000000
# 1 lignes supprimées
# alpha-linolenic-acid_100g : la modification change drastiquement les données, p_value: 0.0019604323147608253
# Calcul du coefficient de variation :
# Avant traitement =  337.88429438677946
# Après traitement =  200.78562495329913
# 4 lignes supprimées
# 5 lignes supprimées
# lactose_100g : la modification change drastiquement les données, p_value: 1.7160403720778212e-13
# Calcul du coefficient de variation :
# Avant traitement =  224.41988054129834
# Après traitement =  282.2257843413767
# 2 lignes supprimées
# 2 lignes supprimées
# vitamin-e_100g : la modification change drastiquement les données, p_value: 0.017595248640294936
# Calcul du coefficient de variation :
# Avant traitement =  1261.8543724075143
# Après traitement =  140.64927514329227
# vitamin-c_100g : la modification change drastiquement les données, p_value: 0.00972655338622698
# Calcul du coefficient de variation :
# Avant traitement =  9432.549136602525
# Après traitement =  480.07428065545855
# vitamin-b1_100g : la modification change drastiquement les données, p_value: 1.7685548895903258e-20
# Calcul du coefficient de variation :
# Avant traitement =  800.7321342192789
# Après traitement =  175.44261941313553
# vitamin-b2_100g : la modification change drastiquement les données, p_value: 9.799294459386072e-31
# Calcul du coefficient de variation :
# Avant traitement =  505.7112882458679
# Après traitement =  149.70408139409972
# vitamin-pp_100g : la modification change drastiquement les données, p_value: 0.016907075388222316
# Calcul du coefficient de variation :
# Avant traitement =  1890.2650565892102
# Après traitement =  163.63811459054696
# folates_100g : la modification change drastiquement les données, p_value: 0.028630325612557957
# Calcul du coefficient de variation :
# Avant traitement =  2450.180327310437
# Après traitement =  151.88328644701707
# potassium_100g : la modification change drastiquement les données, p_value: 0.03602034049870964
# Calcul du coefficient de variation :
# Avant traitement =  1170.3730709728152
# Après traitement =  133.56143943656454
# chloride_100g : la modification change drastiquement les données, p_value: 6.735674572712282e-08
# Calcul du coefficient de variation :
# Avant traitement =  173.43702467373384
# Après traitement =  182.98313424277265
# calcium_100g : la modification change drastiquement les données, p_value: 0.000510030595412935
# Calcul du coefficient de variation :
# Avant traitement =  2732.718213307719
# Après traitement =  184.6860121628647
# phosphorus_100g : la modification change drastiquement les données, p_value: 0.023527433908285145
# Calcul du coefficient de variation :
# Avant traitement =  1942.2484006678292
# Après traitement =  118.93829228184678
# iron_100g : la modification change drastiquement les données, p_value: 0.0020076627472418777
# Calcul du coefficient de variation :
# Avant traitement =  5853.956204874859
# Après traitement =  179.57205424945312
# magnesium_100g : la modification change drastiquement les données, p_value: 0.012190787497682102
# Calcul du coefficient de variation :
# Avant traitement =  2496.7337680169935
# Après traitement =  139.95238448123027
# zinc_100g : la modification change drastiquement les données, p_value: 0.042945987161397164
# Calcul du coefficient de variation :
# Avant traitement =  1082.9038150204233
# Après traitement =  134.51689558564274
# manganese_100g : la modification change drastiquement les données, p_value: 0.019028850487017163
# Calcul du coefficient de variation :
# Avant traitement =  929.4887322342342
# Après traitement =  150.9376466568492
# iodine_100g : la modification change drastiquement les données, p_value: 2.5208362441424445e-06
# Calcul du coefficient de variation :
# Avant traitement =  292.9583558078485
# On observe encore des valeurs aberrantes :
#
#     - On peut retrouver 100 % de fat dans certains produits (huiles d'olives par exemple)
#     - On peut retrouver 100 % de carbohydrates dans certains produits également
#
#     - C'est anormal d'avoir autant de fibre (100%), surtout si nous comparons à la moyenne et ecart-type
#     - Pareil pour les protéines (produits hyperprotéinés ne sont pas autant pourvus)

# %% [markdown]
# Regardons pour les protéines à 100/100g

# %%
with pd.option_context('display.max_columns', None):
    display(data.loc[data["proteins_100g"] == 100])
# Out:
#                  code                                                url  \
# 2466      11110673671  http://world-fr.openfoodfacts.org/produit/0011...
# 36909     41250698784  http://world-fr.openfoodfacts.org/produit/0041...
# 36910     41250698791  http://world-fr.openfoodfacts.org/produit/0041...
# 62661     70552903203  http://world-fr.openfoodfacts.org/produit/0070...
# 79687     75669108367  http://world-fr.openfoodfacts.org/produit/0075...
# 112190   698502500571  http://world-fr.openfoodfacts.org/produit/0698...
# 132545   812603011556  http://world-fr.openfoodfacts.org/produit/0812...
# 150260   872197632261  http://world-fr.openfoodfacts.org/produit/0872...
# 151460   883929140886  http://world-fr.openfoodfacts.org/produit/0883...
# 219775  5051889553625  http://world-fr.openfoodfacts.org/produit/5051...
# 225301  6091035082004  http://world-fr.openfoodfacts.org/produit/6091...
# 226370  7340055304214  http://world-fr.openfoodfacts.org/produit/7340...
#
#                 creator   created_t      created_datetime last_modified_t  \
# 2466    usda-ndb-import  1489143364  2017-03-10T10:56:04Z      1489143364
# 36909   usda-ndb-import  1489057821  2017-03-09T11:10:21Z      1489057821
# 36910   usda-ndb-import  1489057821  2017-03-09T11:10:21Z      1489057821
# 62661   usda-ndb-import  1489065560  2017-03-09T13:19:20Z      1489065560
# 79687   usda-ndb-import  1489134550  2017-03-10T08:29:10Z      1489134550
# 112190          kiliweb  1490902535  2017-03-30T19:35:35Z      1490902535
# 132545  usda-ndb-import  1489075565  2017-03-09T16:06:05Z      1489075565
# 150260  usda-ndb-import  1489134580  2017-03-10T08:29:40Z      1489134580
# 151460          kiliweb  1490383413  2017-03-24T19:23:33Z      1491572789
# 219775          kiliweb  1490383333  2017-03-24T19:22:13Z      1490383333
# 225301          kiliweb  1487698302  2017-02-21T17:31:42Z      1487698304
# 226370          kiliweb  1487699282  2017-02-21T17:48:02Z      1487699282
#
#        last_modified_datetime  \
# 2466     2017-03-10T10:56:04Z
# 36909    2017-03-09T11:10:21Z
# 36910    2017-03-09T11:10:21Z
# 62661    2017-03-09T13:19:20Z
# 79687    2017-03-10T08:29:10Z
# 112190   2017-03-30T19:35:35Z
# 132545   2017-03-09T16:06:05Z
# 150260   2017-03-10T08:29:40Z
# 151460   2017-04-07T13:46:29Z
# 219775   2017-03-24T19:22:13Z
# 225301   2017-02-21T17:31:44Z
# 226370   2017-02-21T17:48:02Z
#
#                                              product_name generic_name  \
# 2466                                   Unflavored Gelatin          NaN
# 36909                                  Unflavored Gelatin          NaN
# 36910                                             Gelatin          NaN
# 62661                                  Unflavored Gelatin          NaN
# 79687                                       Garlic Powder          NaN
# 151460  en:organic,en:eu-organic,fr:ab-agriculture-bio...
# 219775  en:organic,en:eu-organic,fr:ab-agriculture-bio...
# 225301                                                NaN
# 226370  en:organic,en:eu-organic,fr:ab-agriculture-bio...
#
#                                          labels_fr emb_codes emb_codes_tags  \
# 2466                                           NaN       NaN            NaN
# 36909                                          NaN       NaN            NaN
# 36910                                          NaN       NaN            NaN
# 62661                                          NaN       NaN            NaN
# 79687                                          NaN       NaN            NaN
# 112190  Bio,Bio européen,AB Agriculture Biologique       NaN            NaN
# 132545                                         NaN       NaN            NaN
# 150260                                         NaN       NaN            NaN
# 151460  Bio,Bio européen,AB Agriculture Biologique       NaN            NaN
# 219775  Bio,Bio européen,AB Agriculture Biologique       NaN            NaN
# 225301                                         NaN       NaN            NaN
# 226370  Bio,Bio européen,AB Agriculture Biologique       NaN            NaN
#
#        first_packaging_code_geo cities_tags purchase_places stores countries  \
# 2466                        NaN         NaN             NaN    NaN        US
# 36909                       NaN         NaN             NaN    NaN        US
# 36910                       NaN         NaN             NaN    NaN        US
# 62661                       NaN         NaN             NaN    NaN        US
# 79687                       NaN         NaN             NaN    NaN        US
# 112190                      NaN         NaN             NaN    NaN    France
# 132545                      NaN         NaN             NaN    NaN        US
# 150260                      NaN         NaN             NaN    NaN        US
# 151460                      NaN         NaN             NaN    NaN    France
# 219775                      NaN         NaN             NaN    NaN    France
# 225301                      NaN         NaN             NaN    NaN    France
# 226370                      NaN         NaN             NaN    NaN    France
#
#           countries_tags countries_fr  \
# 2466    en:united-states   Etats-Unis
# 36909   en:united-states   Etats-Unis
# 36910   en:united-states   Etats-Unis
# 62661   en:united-states   Etats-Unis
# 79687   en:united-states   Etats-Unis
# 112190         en:france       France
# 132545  en:united-states   Etats-Unis
# 150260  en:united-states   Etats-Unis
# 151460         en:france       France
# 219775         en:france       France
# 225301         en:france       France
# 226370         en:france       France
#
#                                          ingredients_text allergens traces  \
# 2466                                             Gelatin.       NaN    NaN
# 36909                                            Gelatin.       NaN    NaN
# 36910                                            Gelatin.       NaN    NaN
# 62661                                            Gelatin.       NaN    NaN
# 79687                           Granulated garlic powder.       NaN    NaN
# 112190                                                NaN       NaN    NaN
# 132545  Cacao beans*, cane sugar*, cocoa butter*, soy ...       NaN    NaN
# 150260  Sugar, fd&c red 40 lake, carnauba wax and conf...       NaN    NaN
# 151460                                                NaN       NaN    NaN
# 219775                                                NaN       NaN    NaN
# 225301                                                NaN       NaN    NaN
# 226370                                                NaN       NaN    NaN
#
#        traces_tags traces_fr    serving_size  additives_n  \
# 2466           NaN       NaN  7 g (0.25 ONZ)          1.0
# 36909          NaN       NaN       7 g (7 g)          1.0
# 36910          NaN       NaN       7 g (7 g)          1.0
# 62661          NaN       NaN       7 g (7 g)          1.0
# 79687          NaN       NaN  1 g (0.25 tsp)          0.0
# 112190         NaN       NaN             NaN          NaN
# 132545         NaN       NaN     8 g (1 BAR)          1.0
# 150260         NaN       NaN     4 g (1 tsp)          0.0
# 151460         NaN       NaN             NaN          NaN
# 219775         NaN       NaN             NaN          NaN
# 225301         NaN       NaN             NaN          NaN
# 226370         NaN       NaN             NaN          NaN
#
#                                                 additives additives_tags  \
# 2466           [ gelatin -> en:e428  -> exists  -- ok  ]         en:e428
# 36909          [ gelatin -> en:e428  -> exists  -- ok  ]         en:e428
# 36910          [ gelatin -> en:e428  -> exists  -- ok  ]         en:e428
# 62661          [ gelatin -> en:e428  -> exists  -- ok  ]         en:e428
# 79687    [ granulated-garlic-powder -> en:granulated-g...            NaN
# 112190                                                NaN            NaN
# 132545   [ cacao-beans -> en:cacao-beans  ]  [ beans -...        en:e322
# 150260   [ sugar -> en:sugar  ]  [ fd-c-red-40-lake ->...            NaN
# 151460                                                NaN            NaN
# 219775                                                NaN            NaN
# 225301                                                NaN            NaN
# 226370                                                NaN            NaN
#
#              additives_fr  ingredients_from_palm_oil_n  \
# 2466      E428 - Gélatine                          0.0
# 36909     E428 - Gélatine                          0.0
# 36910     E428 - Gélatine                          0.0
# 62661     E428 - Gélatine                          0.0
# 79687                 NaN                          0.0
# 112190                NaN                          NaN
# 132545  E322 - Lécithines                          0.0
# 150260                NaN                          0.0
# 151460                NaN                          NaN
# 219775                NaN                          NaN
# 225301                NaN                          NaN
# 226370                NaN                          NaN
#
#        ingredients_from_palm_oil_tags  \
# 2466                              NaN
# 36909                             NaN
# 36910                             NaN
# 62661                             NaN
# 79687                             NaN
# 112190                            NaN
# 132545                            NaN
# 150260                            NaN
# 151460                            NaN
# 219775                            NaN
# 225301                            NaN
# 226370                            NaN
#
#         ingredients_that_may_be_from_palm_oil_n  \
# 2466                                        0.0
# 36909                                       0.0
# 36910                                       0.0
# 62661                                       0.0
# 79687                                       0.0
# 112190                                      NaN
# 132545                                      0.0
# 150260                                      0.0
# 151460                                      NaN
# 219775                                      NaN
# 225301                                      NaN
# 226370                                      NaN
#
#        ingredients_that_may_be_from_palm_oil_tags nutrition_grade_fr  \
# 2466                                          NaN                NaN
# 36909                                         NaN                  b
# 36910                                         NaN                NaN
# 62661                                         NaN                  b
# 79687                                         NaN                NaN
# 112190                                        NaN                  a
# 132545                                        NaN                  e
# 150260                                        NaN                NaN
# 151460                                        NaN                  a
# 219775                                        NaN                  a
# 225301                                        NaN                  e
# 226370                                        NaN                  c
#
#        pnns_groups_1 pnns_groups_2  \
# 2466             NaN           NaN
# 36909            NaN           NaN
# 36910            NaN           NaN
# 62661            NaN           NaN
# 79687            NaN           NaN
# 112190           NaN           NaN
# 132545           NaN           NaN
# 150260           NaN           NaN
# 151460       unknown       unknown
# 219775           NaN           NaN
# 225301           NaN           NaN
# 226370           NaN           NaN
#
#                                                    states  \
# 2466    en:to-be-completed, en:nutrition-facts-complet...
# 36909   en:to-be-completed, en:nutrition-facts-complet...
# 36910   en:to-be-completed, en:nutrition-facts-complet...
# 62661   en:to-be-completed, en:nutrition-facts-complet...
# 79687   en:to-be-completed, en:nutrition-facts-complet...
# 112190  en:to-be-completed, en:nutrition-facts-complet...
# 132545  en:to-be-completed, en:nutrition-facts-complet...
# 150260  en:to-be-completed, en:nutrition-facts-complet...
# 151460  en:to-be-completed, en:nutrition-facts-complet...
# 219775  en:to-be-completed, en:nutrition-facts-complet...
# 225301  en:to-be-completed, en:nutrition-facts-complet...
# 226370  en:to-be-completed, en:nutrition-facts-complet...
#
#                                               states_tags  \
# 2466    en:to-be-completed,en:nutrition-facts-complete...
# 36909   en:to-be-completed,en:nutrition-facts-complete...
# 36910   en:to-be-completed,en:nutrition-facts-complete...
# 62661   en:to-be-completed,en:nutrition-facts-complete...
# 79687   en:to-be-completed,en:nutrition-facts-complete...
# 112190  en:to-be-completed,en:nutrition-facts-complete...
# 132545  en:to-be-completed,en:nutrition-facts-complete...
# 150260  en:to-be-completed,en:nutrition-facts-complete...
# 151460  en:to-be-completed,en:nutrition-facts-complete...
# 219775  en:to-be-completed,en:nutrition-facts-complete...
# 225301  en:to-be-completed,en:nutrition-facts-complete...
# 226370  en:to-be-completed,en:nutrition-facts-complete...
#
#                                                 states_fr  \
# 2466    A compléter,Informations nutritionnelles compl...
# 36909   A compléter,Informations nutritionnelles compl...
# 36910   A compléter,Informations nutritionnelles compl...
# 62661   A compléter,Informations nutritionnelles compl...
# 79687   A compléter,Informations nutritionnelles compl...
# 112190  A compléter,Informations nutritionnelles compl...
# 132545  A compléter,Informations nutritionnelles compl...
# 150260  A compléter,Informations nutritionnelles compl...
# 151460  A compléter,Informations nutritionnelles compl...
# 219775  A compléter,Informations nutritionnelles compl...
# 225301  A compléter,Informations nutritionnelles compl...
# 226370  A compléter,Informations nutritionnelles compl...
#
#                main_category main_category_fr image_url image_small_url  \
# 2466                     NaN              NaN       NaN             NaN
# 36909                    NaN              NaN       NaN             NaN
# 36910                    NaN              NaN       NaN             NaN
# 62661                    NaN              NaN       NaN             NaN
# 79687                    NaN              NaN       NaN             NaN
# 112190                   NaN              NaN       NaN             NaN
# 132545                   NaN              NaN       NaN             NaN
# 150260                   NaN              NaN       NaN             NaN
# 151460  en:non-food-products  Non alimentaire       NaN             NaN
# 219775                   NaN              NaN       NaN             NaN
# 225301                   NaN              NaN       NaN             NaN
# 226370                   NaN              NaN       NaN             NaN
#
#         energy_100g  energy-from-fat_100g  fat_100g  saturated-fat_100g  \
# 2466         1795.0                   NaN       0.0                 NaN
# 36909        1795.0                   NaN       0.0                 0.0
# 36910        1795.0                   NaN       0.0                 NaN
# 62661        1795.0                   NaN       0.0                 0.0
# 79687           0.0                   NaN       0.0                 0.0
# 112190          4.0                   NaN       NaN                 0.1
# 132545       2301.0                   NaN      35.0                22.5
# 150260       1674.0                   NaN       0.0                 NaN
# 151460          4.0                   NaN       NaN                 0.0
# 219775          4.0                   NaN       NaN                 0.0
# 225301        418.0                   NaN       NaN               100.0
# 226370         21.0                   NaN       NaN                 5.0
#
#         caprylic-acid_100g  capric-acid_100g  lauric-acid_100g  \
# 2466                   NaN               NaN               NaN
# 36909                  NaN               NaN               NaN
# 36910                  NaN               NaN               NaN
# 62661                  NaN               NaN               NaN
# 79687                  NaN               NaN               NaN
# 112190                 NaN               NaN               NaN
# 132545                 NaN               NaN               NaN
# 150260                 NaN               NaN               NaN
# 151460                 NaN               NaN               NaN
# 219775                 NaN               NaN               NaN
# 225301                 NaN               NaN               NaN
# 226370                 NaN               NaN               NaN
#
#         myristic-acid_100g  palmitic-acid_100g  stearic-acid_100g  \
#
odine_100g  caffeine_100g  taurine_100g  ph_100g  \
# 2466            NaN            NaN           NaN      NaN
# 36909           NaN            NaN           NaN      NaN
# 36910           NaN            NaN           NaN      NaN
# 62661           NaN            NaN           NaN      NaN
# 79687           NaN            NaN           NaN      NaN
# 112190          NaN            NaN           NaN      NaN
# 132545          NaN            NaN           NaN      NaN
# 150260          NaN            NaN           NaN      NaN
# 151460          NaN            NaN           NaN      NaN
# 219775          NaN            NaN           NaN      NaN
# 225301          NaN            NaN           NaN      NaN
# 226370          NaN            NaN           NaN      NaN
#
#         fruits-vegetables-nuts_100g  collagen-meat-protein-ratio_100g  \
# 2466                            NaN                               NaN
# 36909                           NaN                               NaN
# 36910                           NaN                               NaN
# 62661                           NaN                               NaN
# 79687                           NaN                               NaN
# 112190                          NaN                               NaN
# 132545                          NaN                               NaN
# 150260                          NaN                               NaN
# 151460                          NaN                               NaN
# 219775                          NaN                               NaN
# 225301                          NaN                               NaN
# 226370                          NaN                               NaN
#
#         cocoa_100g  carbon-footprint_100g  nutrition-score-fr_100g  \
# 2466           NaN                    NaN                      NaN
# 36909          NaN                    NaN                      1.0
# 36910          NaN                    NaN                      NaN
# 62661          NaN                    NaN                      1.0
# 79687          NaN                    NaN                      NaN
# 112190         NaN                    NaN                    -10.0
# 132545         NaN                    NaN                     24.0
# 150260         NaN                    NaN                      NaN
# 151460         NaN                    NaN                    -10.0
# 219775         NaN                    NaN                    -10.0
# 225301         NaN                    NaN                     24.0
# 226370         NaN                    NaN                     10.0
#
#         nutrition-score-uk_100g
# 2466                        NaN
# 36909                       1.0
# 36910                       NaN
# 62661                       1.0
# 79687                       NaN
# 112190                    -10.0
# 132545                     24.0
# 150260                      NaN
# 151460                    -10.0
# 219775                    -10.0
# 225301                     24.0
# 226370                     10.0

# %% [markdown]
# On peut observer que de fausses informations ont été entrées (des films).
#
# On élimine sur ce critère : "ingredients_text", si vide on enlève

# %%
index_elim = data.loc[(data["ingredients_text"].isnull()) & (data["proteins_100g"] == 100)].index
data = data.loc[~data.index.isin(index_elim)]

# %% [markdown]
# Observons les fibres à 100g/100g maintenant

# %%
with pd.option_context('display.max_columns', None):
    display(data.loc[data["fiber_100g"] == 100])
# Out:
#                  code                                                url  \
# 9498      12511946067  http://world-fr.openfoodfacts.org/produit/0012...
# 76568     74410530525  http://world-fr.openfoodfacts.org/produit/0074...
# 139416   850196003060  http://world-fr.openfoodfacts.org/produit/0850...
# 139417   850196003091  http://world-fr.openfoodfacts.org/produit/0850...
# 202821  3590670000174  http://world-fr.openfoodfacts.org/produit/3590...
#
#                 creator   created_t      created_datetime last_modified_t  \
# 9498    usda-ndb-import  1489063583  2017-03-09T12:46:23Z      1489063583
# 76568   usda-ndb-import  1489143631  2017-03-10T11:00:31Z      1489143631
# 139416  usda-ndb-import  1489067170  2017-03-09T13:46:10Z      1489067170
# 139417  usda-ndb-import  1489061180  2017-03-09T12:06:20Z      1489061181
# 202821          kiliweb  1492441820  2017-04-17T15:10:20Z      1492441822
#
#        last_modified_datetime  \
# 9498     2017-03-09T12:46:23Z
# 76568    2017-03-10T11:00:31Z
# 139416   2017-03-09T13:46:10Z
# 139417   2017-03-09T12:06:21Z
# 202821   2017-04-17T15:10:22Z
#
#                                              product_name generic_name  \
# 9498                                           Sweeteners          NaN
# 76568                        Yamashin, Powdered Agar-Agar          NaN
# 139416                         Powdered Sweetener Packets          NaN
# 139417  Premium Organic Stevia, Powdered Sweetener Pac...          NaN
# 202821                                        Noix sèches          NaN
#
#        quantity packaging packaging_tags                       brands  \
# 9498        NaN       NaN            NaN                    Wholesome
# 76568       NaN       NaN            NaN  Wismettac Asian Foods  Inc.
# 139416      NaN       NaN            NaN                        Pyure
# 139417      NaN       NaN            NaN                        Pyure
# 202821      NaN       NaN            NaN                     Pepinoix
#
#                       brands_tags categories categories_tags categories_fr  \
# 9498                    wholesome        NaN             NaN           NaN
# 76568   wismettac-asian-foods-inc        NaN             NaN           NaN
# 139416                      pyure        NaN             NaN           NaN
# 139417                      pyure        NaN             NaN           NaN
# 202821                   pepinoix        NaN             NaN           NaN
#
#        origins origins_tags manufacturing_places manufacturing_places_tags  \
# 9498       NaN          NaN                  NaN                       NaN
# 76568      NaN          NaN                  NaN                       NaN
# 139416     NaN          NaN                  NaN                       NaN
# 139417     NaN          NaN                  NaN                       NaN
# 202821     NaN          NaN                  NaN                       NaN
#
#        labels labels_tags labels_fr emb_codes emb_codes_tags  \
# 9498      NaN         NaN       NaN       NaN            NaN
# 76568     NaN         NaN       NaN       NaN            NaN
# 139416    NaN         NaN       NaN       NaN            NaN
# 139417    NaN         NaN       NaN       NaN            NaN
# 202821    NaN         NaN       NaN       NaN            NaN
#
#        first_packaging_code_geo cities_tags purchase_places stores countries  \
# 9498                        NaN         NaN             NaN    NaN        US
# 76568                       NaN         NaN             NaN    NaN        US
# 139416                      NaN         NaN             NaN    NaN        US
# 139417                      NaN         NaN             NaN    NaN        US
# 202821                      NaN         NaN             NaN    NaN    France
#
#           countries_tags countries_fr  \
# 9498    en:united-states   Etats-Unis
# 76568   en:united-states   Etats-Unis
# 139416  en:united-states   Etats-Unis
# 139417  en:united-states   Etats-Unis
# 202821         en:france       France
#
#                                          ingredients_text allergens traces  \
# 9498    Organic agave inulin, organic stevia extract (...       NaN    NaN
# 76568                                            Seaweed.       NaN    NaN
# 139416  Organic agave inulin, organic stevia leaf extr...       NaN    NaN
# 139417  Organic agave inulin, organic stevia leaf extr...       NaN    NaN
# 202821                                        Noix sèches       NaN    NaN
#
#        traces_tags traces_fr     serving_size  additives_n  \
# 9498           NaN       NaN    1 g (0.5 tsp)          1.0
# 76568          NaN       NaN  4 g (1 PACKAGE)          0.0
# 139416         NaN       NaN        1 g (1 g)          0.0
# 139417         NaN       NaN        1 g (1 g)          0.0
# 202821         NaN       NaN              NaN          0.0
#
#                                                 additives additives_tags  \
# 9498     [ organic-agave-inulin -> en:organic-agave-in...        en:e551
# 76568                         [ seaweed -> en:seaweed  ]             NaN
# 139416   [ organic-agave-inulin -> en:organic-agave-in...            NaN
# 139417   [ organic-agave-inulin -> en:organic-agave-in...            NaN
# 202821   [ noix-seches -> fr:noix-seches  ]  [ noix ->...            NaN
#
#                       additives_fr  ingredients_from_palm_oil_n  \
# 9498    E551 - Dioxyde de silicium                          0.0
# 76568                          NaN                          0.0
# 139416                         NaN                          0.0
# 139417                         NaN                          0.0
# 202821                         NaN                          0.0
#
#        ingredients_from_palm_oil_tags  \
# 9498                              NaN
# 76568                             NaN
# 139416                            NaN
# 139417                            NaN
# 202821                            NaN
#
#         ingredients_that_may_be_from_palm_oil_n  \
# 9498                                        0.0
# 76568                                       0.0
# 139416                                      0.0
# 139417                                      0.0
# 202821                                      0.0
#
#        ingredients_that_may_be_from_palm_oil_tags nutrition_grade_fr  \
# 9498                                          NaN                NaN
# 76568                                         NaN                  b
# 139416                                        NaN                NaN
# 139417                                        NaN                NaN
# 202821                                        NaN                  a
#
#        pnns_groups_1 pnns_groups_2  \
# 9498             NaN           NaN
# 76568            NaN           NaN
# 139416           NaN           NaN
# 139417           NaN           NaN
# 202821       unknown       unknown
#
#                                                    states  \
# 9498    en:to-be-completed, en:nutrition-facts-complet...
# 76568   en:to-be-completed, en:nutrition-facts-complet...
# 139416  en:to-be-completed, en:nutrition-facts-complet...
# 139417  en:to-be-completed, en:nutrition-facts-complet...
# 202821  en:to-be-completed, en:nutrition-facts-complet...
#
#                                               states_tags  \
# 9498    en:to-be-completed,en:nutrition-facts-complete...
# 76568   en:to-be-completed,en:nutrition-facts-complete...
# 139416  en:to-be-completed,en:nutrition-facts-complete...
# 139417  en:to-be-completed,en:nutrition-facts-complete...
# 202821  en:to-be-completed,en:nutrition-facts-complete...
#
#                                                 states_fr main_category  \
# 9498    A compléter,Informations nutritionnelles compl...           NaN
# 76568   A compléter,Informations nutritionnelles compl...           NaN
# 139416  A compléter,Informations nutritionnelles compl...           NaN
# 139417  A compléter,Informations nutritionnelles compl...           NaN
# 202821  A compléter,Informations nutritionnelles compl...           NaN
#
#        main_category_fr image_url image_small_url  energy_100g  \
# 9498                NaN       NaN             NaN          0.0
# 76568               NaN       NaN             NaN       1046.0
# 139416              NaN       NaN             NaN          0.0
# 139417              NaN       NaN             NaN          0.0
# 202821              NaN       NaN             NaN          0.0
#
#         energy-from-fat_100g  fat_100g  saturated-fat_100g  \
# 9498                     NaN       0.0                 NaN
# 76568                    NaN       0.0                 0.0
# 139416                   NaN       0.0                 NaN
# 139417                   NaN       0.0                 NaN
# 202821                   NaN       0.0                 0.0
#
#         caprylic-acid_100g  capric-acid_100g  lauric-acid_100g  \
# 9498                   NaN               NaN               NaN
# 76568                  NaN               NaN               NaN
# 139416                 NaN               NaN               NaN
# 139417                 NaN               NaN               NaN
# 202821                 NaN               NaN               NaN
#
#         myristic-acid_100g  palmitic-acid_100g  stearic-acid_100g  \
#
assium_100g  chloride_100g  calcium_100g  phosphorus_100g  \
# 9498               NaN            NaN           NaN              NaN
# 76568              NaN            NaN           0.5              NaN
# 139416             NaN            NaN           NaN              NaN
# 139417             NaN            NaN           NaN              NaN
# 202821             NaN            NaN           NaN              NaN
#
#         iron_100g  magnesium_100g  zinc_100g  copper_100g  manganese_100g  \
# 9498          NaN             NaN        NaN          NaN             NaN
# 76568       0.009             NaN        NaN          NaN             NaN
# 139416        NaN             NaN        NaN          NaN             NaN
# 139417        NaN             NaN        NaN          NaN             NaN
# 202821        NaN             NaN        NaN          NaN             NaN
#
#         fluoride_100g  selenium_100g  chromium_100g  molybdenum_100g  \
# 9498              NaN            NaN            NaN              NaN
# 76568             NaN            NaN            NaN              NaN
# 139416            NaN            NaN            NaN              NaN
# 139417            NaN            NaN            NaN              NaN
# 202821            NaN            NaN            NaN              NaN
#
#         iodine_100g  caffeine_100g  taurine_100g  ph_100g  \
# 9498            NaN            NaN           NaN      NaN
# 76568           NaN            NaN           NaN      NaN
# 139416          NaN            NaN           NaN      NaN
# 139417          NaN            NaN           NaN      NaN
# 202821          NaN            NaN           NaN      NaN
#
#         fruits-vegetables-nuts_100g  collagen-meat-protein-ratio_100g  \
# 9498                            NaN                               NaN
# 76568                           NaN                               NaN
# 139416                          NaN                               NaN
# 139417                          NaN                               NaN
# 202821                          0.0                               NaN
#
#         cocoa_100g  carbon-footprint_100g  nutrition-score-fr_100g  \
# 9498           NaN                    NaN                      NaN
# 76568          NaN                    NaN                      0.0
# 139416         NaN                    NaN                      NaN
# 139417         NaN                    NaN                      NaN
# 202821         NaN                    NaN                     -5.0
#
#         nutrition-score-uk_100g
# 9498                        NaN
# 76568                       0.0
# 139416                      NaN
# 139417                      NaN
# 202821                     -5.0

# %% [markdown]
# 100 g de fibre pourrait être correct pour ces aliments

# %% [markdown]
# #### <a name = "T3C4">4. Correction de la feature Fat_100g</a>

# %% [markdown]
# Le fat_100g est une feature majeure.
#
# On recherche les valeurs pour lesquelles la somme des fats est supérieure à 'fat_100g' car ce sont des valeurs aberrantes

# %%
## Permet de corriger la valeur de fat_100g

def fat_corr(df):
    # Recherche des conditions où la somme des fats est plus grande que le total
    fats = ["saturated-fat_100g", "monounsaturated-fat_100g", "polyunsaturated-fat_100g", "trans-fat_100g"]

    # On récupère les index qui remplissent cette condition
    index_fat = df.loc[df[fats].sum(axis = 1) > df["fat_100g"]].index

    # On récupère les index où il n'y a pas de valeur entrées pour les fats
    index_nulle_fat = df.loc[df["fat_100g"].isnull()].index

    mask = copy.deepcopy(df)
    
    # On change la valeur par la somme
    df.loc[df.index.isin(index_fat), "fat_100g"] = df[fats].sum(axis = 1)
    df.loc[(df.index.isin(index_nulle_fat)) & (df[fats].sum(axis = 1) > 0), "fat_100g"] = df[fats].sum(axis = 1)

    print("Il y a ", index_fat.shape[0], "valeurs incorrectes et",index_nulle_fat.shape[0],"valeurs nulles.")
    print("Après correction, il y a", df.loc[(df["fat_100g"] > 100) & (df["fat_100g"] <= 110)].shape[0],"valeurs de fat entre 100 et 110 après correction")
    print("Après correction, il y a", df.loc[df["fat_100g"] > 110].shape[0], "valeurs de fat au dessus de 110 après correction")
    print("Après correction, il y a", df[df["fat_100g"].isnull()].shape[0],"valeurs de fat nulle après correction")
    
    # Pour corriger les erreurs de corrections
    df = ajustement(df, "fat_100g")
    
    
    # Test statistique
    # Sur les valeurs modifiées
    resultcorrection_ttest(mask[~mask.index.isin(index_nulle_fat)], df[~df.index.isin(index_nulle_fat)], "fat_100g", False)
    

    
    return df

# %%
display(data["fat_100g"].describe())

data = fat_corr(data)

display(data["fat_100g"].describe())
# Out:
# count    229805.000000
# mean         12.622016
# std          16.931071
# min           0.000000
# 25%           0.000000
# 50%           5.310000
# 75%          20.000000
# max         100.000000
# Name: fat_100g, dtype: float64
# Il y a  2405 valeurs incorrectes et 21647 valeurs nulles.
# Après correction, il y a 117 valeurs de fat entre 100 et 110 après correction
# Après correction, il y a 4 valeurs de fat au dessus de 110 après correction
# Après correction, il y a 6286 valeurs de fat nulle après correction
# 4 lignes supprimées
# count    245162.000000
# mean         12.263180
# std          16.679074
# min           0.000000
# 25%           0.100000
# 50%           5.000000
# 75%          19.700000
# max         100.000000
# Name: fat_100g, dtype: float64

# %% [markdown]
# Il reste un grand nombre de valeurs nulles, néanmoins un grand nombre a pu être comblé en mesurant la valeur de fat avec les autres types de fat.
#
# On observe que la distribution est modifié significativement. Mais la mesure du coefficient de variation montre que cette distribution est assez similaire à la distribution précédent la modification.
#
# On tentera de compléter les valeurs manquantes par la suite.

# %%
## Fonction pour visualiser la distribution d'une feature

def figure_feature(df, feature, style = "violinplot"):
    plt.figure(figsize=(12,6))

    if style == "boxplot":
        sns.boxplot(data = df, y = feature, color = "red", orient = "h")    
    elif style == "violinplot":
        sns.violinplot(data = df, y = feature, color = "red", orient = "h")

    plt.title("Distribution de la feature : "+str(feature), fontsize = 18)
    plt.xticks(rotation=0)
    plt.yticks(rotation=0)
    plt.xlabel(str(feature), fontsize=18)
    plt.ylabel("g/100g", fontsize=14)

    plt.show()

# %%
figure_feature(data, "fat_100g")
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %% [markdown]
# Une majorité des produits ont une faible teneur en gras.

# %% [markdown]
# #### <a name = "T3C5">5. Correction de la feature saturated-fat_100g</a>

# %% [markdown]
# Le saturated-fat_100g est une feature majeure.
#
# On recherche le nombre de valeurs manquantes.
#
# Puis on recalcul la valeur de fat-saturated_100g quand celle ci est manquante.
#
# On pourra la mesurer à l'aide de la valeur fat remplie précédement et les autres paramètres de fat disponible.

# %%
def fat_saturated_corr(df):
    # Recherche des conditions où la somme des fats est plus grande que le total
    saturated = ["monounsaturated-fat_100g", "polyunsaturated-fat_100g", "trans-fat_100g"]
    
    # On récupère les index où la feature n'est pas rempli
    index_saturated = data.loc[data["saturated-fat_100g"].isnull()].index

    print("Il y a ",index_saturated.shape[0],"valeurs nulles.")

    mask = copy.deepcopy(df)
    
    # On met 0 quand fat = 0
    data.loc[(data.index.isin(index_saturated)) & (data["fat_100g"] == 0), "saturated-fat_100g"] = data["fat_100g"]
    index_saturated = data.loc[data["saturated-fat_100g"].isnull()].index

    print("Il reste ",index_saturated.shape[0],"valeurs nulles après correction avec fat = 0 = saturated_fat.")

    # On calcul saturated fat quand on a toutes les features d'entrées
    data.loc[(data.index.isin(index_saturated)) & (data[saturated].sum(axis = 1)> 0), "saturated-fat_100g"] =  data["fat_100g"] - data[saturated].sum(axis = 1)
    index_saturated = data.loc[data["saturated-fat_100g"].isnull()].index

    print("Il reste ",index_saturated.shape[0],"valeurs nulles après correction par saturated = fat - monounsat - polyunsa - trans-fat_100g")
    
    df = ajustement(df, "saturated-fat_100g")
   
    # Test statistique
    resultcorrection_ttest(mask, df, "saturated-fat_100g", False)

    return df

# %%
display(data["saturated-fat_100g"].describe())

data = fat_saturated_corr(data)

display(data["saturated-fat_100g"].describe())
# Out:
# count    218835.000000
# mean          5.111693
# std           7.855197
# min           0.000000
# 25%           0.000000
# 50%           1.800000
# 75%           7.140000
# max         100.000000
# Name: saturated-fat_100g, dtype: float64
# Il y a  32613 valeurs nulles.
# Il reste  10780 valeurs nulles après correction avec fat = 0 = saturated_fat.
# Il reste  10697 valeurs nulles après correction par saturated = fat - monounsat - polyunsa - trans-fat_100g
# saturated-fat_100g : la modification change drastiquement les données, p_value: 1.9425087173538218e-91
# Calcul du coefficient de variation :
# Avant traitement =  153.6711483955139
# Après traitement =  164.20487156549015
# count    240751.000000
# mean          4.648034
# std           7.632299
# min           0.000000
# 25%           0.000000
# 50%           1.250000
# 75%           6.670000
# max         100.000000
# Name: saturated-fat_100g, dtype: float64

# %% [markdown]
# Après remplissage des valeurs manquantes, il reste 10000 valeurs manquantes.
#
# Les modifications effectuées modifient la distribution des valeurs.
#
# Le coeffivient de variation le confirme, avec son augmentation après modification.
#
# Les valeurs ajoutées n'ont donc pas la même distribution que celle qui étaient présentes.

# %%
figure_feature(data, "saturated-fat_100g")
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %% [markdown]
# Similaire à ce qui est retrouvé avec la feature fat

# %% [markdown]
# #### <a name = "T3C6">6. Correction des la feature carbohydrates</a>

# %% [markdown]
# Le carbohydrate_100g est une feature majeure.
#
# On recherche les valeurs pour lesquelles la somme des carbohydrates ("sugars_100g", "starch_100g", "fiber_100g") est supérieure à la valeur de 'carbohydrates_100g, ce qui correspond à une valeur aberrante.

# %%
def carbohydrate_corr(df):
    # Recherche des conditions où la somme des carbohydrates est plus grande que le total
    carbohydrates = ["sugars_100g", "starch_100g", "fiber_100g"]

    # On récupère les index qui remplissent cette condition
    index_sum_carbo = df.loc[df[carbohydrates].sum(axis = 1) > df["carbohydrates_100g"]].index

    # On récupère les index où il n'y a pas de valeur entrées pour les carbohydrates
    index_nulle_carbo = df.loc[df["carbohydrates_100g"].isnull()].index

    mask = copy.deepcopy(df)

    # On change la valeur par la somme
    df.loc[df.index.isin(index_sum_carbo), "carbohydrates_100g"] = df[carbohydrates].sum(axis = 1)
    df.loc[(df.index.isin(index_nulle_carbo)) & (df[carbohydrates].sum(axis = 1) > 0), "carbohydrates_100g"] = df[carbohydrates].sum(axis = 1)

    print("Il y a ", index_sum_carbo.shape[0], "valeurs incorrectes et",index_nulle_carbo.shape[0],"valeurs nulles.")
    print("Après correction, il y a", df.loc[(df["carbohydrates_100g"] > 100) & (df["carbohydrates_100g"] <= 110)].shape[0],"valeurs de carbohydrates entre 100 et 110 après correction")
    print("Après correction, il y a", df.loc[df["carbohydrates_100g"] > 110].shape[0], "valeurs de carbohydrates au dessus de 110 après correction")
    print("Après correction, il reste", df[df["carbohydrates_100g"].isnull()].shape[0],"valeurs de carbohydrates nulles")
    
    df = ajustement(df, "carbohydrates_100g")
    
    # Test statistique
    # Sur valeurs modifiées non nulle
    resultcorrection_ttest(mask, df, "carbohydrates_100g", False)
    
    return df

# %%
display(data["carbohydrates_100g"].describe())

data = carbohydrate_corr(data)

display(data["carbohydrates_100g"].describe())
# Out:
# count    229486.000000
# mean         32.373699
# std          28.964316
# min           0.000000
# 25%           6.350000
# 50%          21.430000
# 75%          58.700000
# max         100.000000
# Name: carbohydrates_100g, dtype: float64
# Il y a  15080 valeurs incorrectes et 21962 valeurs nulles.
# Après correction, il y a 15 valeurs de carbohydrates entre 100 et 110 après correction
# Après correction, il y a 13 valeurs de carbohydrates au dessus de 110 après correction
# Après correction, il reste 5371 valeurs de carbohydrates nulles
# 13 lignes supprimées
# carbohydrates_100g : la modification change drastiquement les données, p_value: 4.724823820610983e-22
# Calcul du coefficient de variation :
# Avant traitement =  89.46866168072297
# Après traitement =  91.02750381551633
# count    246064.000000
# mean         31.565538
# std          28.733321
# min           0.000000
# 25%           6.000000
# 50%          20.000000
# 75%          57.140000
# max         100.000000
# Name: carbohydrates_100g, dtype: float64

# %% [markdown]
# On observe qu'il y avait un certain nombre de valeurs aberrantes (somme des carbo > valeur carbo).
#
# Après correction, on observe des valeurs supérieures à 100. Cela pourrait provenir de valeurs mal corrigées précédemment. Ces lignes sont écartées.
#
# On oberve que les modifications réalisées entraînent une modification significative de la distribution des valeurs. Ce qui est normal car pour 15080 valeurs, la quantité de carbohydrates est remesuré positivement.
#
# Quand on analyse la distribution par boxplot avant et après, la médiane diminue très peu.
#
# Donc la modification réalisée ne change pas dratiquement les valeurs.
#
# Le coefficient de variation montre que les valeurs se sont rapprochées de la moyenne.

# %%
figure_feature(data, "carbohydrates_100g")
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %% [markdown]
# Deux types de produits :
# soient riches, soit pauvres en carbohydrates.

# %% [markdown]
# #### <a name = "T3C7">7. Correction des features Salt/Sodium</a>

# %% [markdown]
# Le salt_100g est une feature majeure.

# %%
# Calcul de la correlation entre Salt et Sodium
data["salt_100g"].corr(data["sodium_100g"])
# Out:
# 0.9999999762923238

# %% [markdown]
# Forte corrélation, ce qui est attendu.

# %%
data[["sodium_100g", "salt_100g"]].describe()
# Out:
#          sodium_100g      salt_100g
# count  241551.000000  241591.000000
# mean        0.627719       1.594149
# std         2.512957       6.382494
# min         0.000000       0.000000
# 25%         0.027000       0.068580
# 50%         0.232000       0.589280
# 75%         0.536000       1.361440
# max       100.000000     254.000000

# %% [markdown]
# On retrouve des valeurs > 100
#
# 100g de sel de table (salt) = ~39,33 - 39,37 g de sodium.
#
# Voyons voir si nous retrouvons cette valeur.

# %%
data["sodium_100g"].mean()/data["salt_100g"].mean() * 100
# Out:
# 39.37643718850233

# %% [markdown]
# On est très proche de la valeur.
# Dans tous les cas le sodium ne peut pa être supérieur à 39,37 g.
#
# Corrigeons dans un premier temps le sel.

# %%
with pd.option_context('display.max_columns', None):
    display(data[data["salt_100g"] > 100])
# Out:
#                   code                                                url  \
# 408         2124810206  http://world-fr.openfoodfacts.org/produit/0002...
# 3037       11110825261  http://world-fr.openfoodfacts.org/produit/0011...
# 6375       11161036074  http://world-fr.openfoodfacts.org/produit/0011...
# 16704      21140024862  http://world-fr.openfoodfacts.org/produit/0021...
# 16940      21248102585  http://world-fr.openfoodfacts.org/produit/0021...
# ...                ...                                                ...
# 156930        20035433  http://world-fr.openfoodfacts.org/produit/2003...
# 194138   3423720002432  http://world-fr.openfoodfacts.org/produit/3423...
# 194811   3445850070259  http://world-fr.openfoodfacts.org/produit/3445...
# 223450  54130979000399  http://world-fr.openfoodfacts.org/produit/5413...
# 238257   8033224177274  http://world-fr.openfoodfacts.org/produit/8033...
#
#                            creator   created_t      created_datetime  \
# 408                usda-ndb-import  1489090470  2017-03-09T20:14:30Z
# 3037               usda-ndb-import  1489064104  2017-03-09T12:55:04Z
# 6375               usda-ndb-import  1489090327  2017-03-09T20:12:07Z
# 16704              usda-ndb-import  1489090461  2017-03-09T20:14:21Z
# 16940              usda-ndb-import  1489061314  2017-03-09T12:08:34Z
# ...                            ...         ...                   ...
# 156930             usda-ndb-import  1489050365  2017-03-09T09:06:05Z
# 194138                       bea51  1474633270  2016-09-23T12:21:10Z
# 194811  openfoodfacts-contributors  1442693426  2015-09-19T20:10:26Z
# 223450             usda-ndb-import  1489066144  2017-03-09T13:29:04Z
# 238257             usda-ndb-import  1489064647  2017-03-09T13:04:07Z
#
#        last_modified_t last_modified_datetime  \
# 408         1489090470   2017-03-09T20:14:30Z
# 3037        1489064104   2017-03-09T12:55:04Z
# 6375        1489090327   2017-03-09T20:12:07Z
# 16704       1489090461   2017-03-09T20:14:21Z
# 16940       1489061314   2017-03-09T12:08:34Z
# ...                ...                    ...
# 156930      1489050365   2017-03-09T09:06:05Z
# 194138      1485984093   2017-02-01T21:21:33Z
# 194811      1488550094   2017-03-03T14:08:14Z
# 223450      1489066144   2017-03-09T13:29:04Z
# 238257      1489064647   2017-03-09T13:04:07Z
#
#                                             product_name  \
# 408                               Mediterranean Sea Salt
# 3037                                  Coarse Kosher Salt
# 6375                                       Fine Sea Salt
# 16704                     Mediterranean Sea Salt Grinder
# 16940                                Himalayan Pink Salt
# ...                                                  ...
# 156930                     Mediterranean Coarse Sea Salt
# 194138                                         Keeny Bio
# 194811                       Sel de Guérande Label Rouge
# 223450                                 Organic Dill Salt
# 238257  Tartufi Di Fassia, Grey Salt With White Truffles
#
#                    generic_name quantity          packaging  \
# 408                         NaN      NaN                NaN
# 3037                        NaN      NaN                NaN
# 6375                        NaN      NaN                NaN
# 16704                       NaN      NaN                NaN
# 16940                       NaN      NaN                NaN
# ...                         ...      ...                ...
# 156930                      NaN      NaN                NaN
# 194138  Moelleux au lait écrémé    135 g  Paquet individuel
# 194811          Sel marin moulu    125 g             Carton
# 223450                      NaN      NaN                NaN
# 238257                      NaN      NaN                NaN
#
#            packaging_tags         brands    brands_tags  \
# 408                   NaN  Olde Thompson  olde-thompson
# 3037                  NaN         Kroger         kroger
# 6375                  NaN       Shurfine       shurfine
# 16704                 NaN     Winn Dixie     winn-dixie
# 16940                 NaN  Olde Thompson  olde-thompson
# ...                   ...            ...            ...
# 156930                NaN   Fresh & Easy     fresh-easy
# 194138  paquet-individuel     Bio Soleil     bio-soleil
# 194811             carton  Le guerandais  le-guerandais
# 223450                NaN      Aromasong      aromasong
# 238257                NaN     D.O.S. Srl      d-o-s-srl
#
#                                                categories  \
# 408                                                   NaN
# 3037                                                  NaN
# 6375                                                  NaN
# 16704                                                 NaN
# 16940                                                 NaN
# ...                                                   ...
# 156930                                                NaN
# 194138  Snacks sucrés,Biscuits et gâteaux,Desserts,Gât...
# 194811  Epicerie,Condiments,Sels,Sels marins,Sels de G...
# 223450                                                NaN
# 238257                                                NaN
#
#                                           categories_tags  \
# 408                                                   NaN
# 3037                                                  NaN
# 6375                                                  NaN
# 16704                                                 NaN
# 16940                                                 NaN
# ...                                                   ...
# 156930                                                NaN
# 194138  en:sugary-snacks,en:biscuits-and-cakes,en:dess...
# 194811  en:groceries,en:condiments,en:salts,en:sea-sal...
# 223450                                                NaN
# 238257                                                NaN
#
#                                             categories_fr origins  \
# 408                                                   NaN     NaN
# 3037                                                  NaN     NaN
# 6375                                                  NaN     NaN
# 16704                                                 NaN     NaN
# 16940                                                 NaN     NaN
# ...                                                   ...     ...
# 156930                                                NaN     NaN
# 194138  Snacks sucrés,Biscuits et gâteaux,Desserts,Gât...     NaN
# 194811  Epicerie,Condiments,Sels,Sels marins,Sels de G...     NaN
# 223450                                                NaN     NaN
# 238257                                                NaN     NaN
#
#        origins_tags                       manufacturing_places  \
# 408             NaN                                        NaN
# 3037            NaN                                        NaN
# 6375            NaN                                        NaN
# 16704           NaN                                        NaN
# 16940           NaN                                        NaN
# ...             ...                                        ...
# 156930          NaN                                        NaN
# 194138          NaN                                     Annecy
# 194811          NaN  France,Bretagne,Loire Atlantique,Guérande
# 223450          NaN                                        NaN
# 238257          NaN                                        NaN
#
#                         manufacturing_places_tags  \
# 408                                           NaN
# 3037                                          NaN
# 6375                                          NaN
# 16704                                         NaN
# 16940                                         NaN
# ...                                           ...
# 156930                                        NaN
# 194138                                     annecy
# 194811  france,bretagne,loire-atlantique,guerande
# 223450                                        NaN
# 238257                                        NaN
#
#                                                    labels  \
# 408                                                   NaN
# 3037                                                  NaN
# 6375                                                  NaN
# 16704                                                 NaN
# 16940                                                 NaN
# ...                                                   ...
# 156930                                                NaN
# 194138  Sans huile de palme,AB Agriculture Biologique,...
# 194811                IGP,Label Rouge,Produit en Bretagne
# 223450                                                NaN
# 238257                                                NaN
#
#                                               labels_tags  \
# 408                                                   NaN
# 3037                                                  NaN
# 6375                                                  NaN
# 16704                                                 NaN
# 16940                                                 NaN
# ...                                                   ...
# 156930                                                NaN
# 194138  en:organic,en:eu-organic,en:palm-oil-free,fr:a...
# 194811      en:pgi,en:label-rouge,en:produced-in-bretagne
# 223450                                                NaN
# 238257                                                NaN
#
#                                                 labels_fr   emb_codes  \
# 408                                                   NaN         NaN
# 3037                                                  NaN         NaN
# 6375                                                  NaN         NaN
# 16704                                                 NaN         NaN
# 16940                                                 NaN         NaN
# ...                                                   ...         ...
# 156930                                                NaN         NaN
# 194138  Bio,Bio européen,Sans huile de palme,AB Agricu...         NaN
# 194811                IGP,Label Rouge,Produit en Bretagne  EMB 44069B
# 223450                                                NaN         NaN
# 238257                                                NaN         NaN
#
#        emb_codes_tags first_packaging_code_geo  \
# 408               NaN                      NaN
# 3037              NaN                      NaN
# 6375              NaN                      NaN
# 16704             NaN                      NaN
# 16940             NaN                      NaN
# ...               ...                      ...
# 156930            NaN                      NaN
# 194138            NaN                      NaN
# 194811     emb-44069b      47.333333,-2.433333
# 223450            NaN                      NaN
# 238257            NaN                      NaN
#
#                              cities_tags purchase_places   stores countries  \
# 408                                  NaN             NaN      NaN        US
# 3037                                 NaN             NaN      NaN        US
# 6375                                 NaN             NaN      NaN        US
# 16704                                NaN             NaN      NaN        US
# 16940                                NaN             NaN      NaN        US
# ...                                  ...             ...      ...       ...
# 156930                               NaN             NaN      NaN        US
# 194138                               NaN    Reims,France  Naturea    France
# 194811  guerande-loire-atlantique-france             NaN      NaN    France
# 223450                               NaN             NaN      NaN        US
# 238257                               NaN             NaN      NaN        US
#
#           countries_tags countries_fr  \
# 408     en:united-states   Etats-Unis
# 3037    en:united-states   Etats-Unis
# 6375    en:united-states   Etats-Unis
# 16704   en:united-states   Etats-Unis
# 16940   en:united-states   Etats-Unis
# ...                  ...          ...
# 156930  en:united-states   Etats-Unis
# 194138         en:france       France
# 194811         en:france       France
# 223450  en:united-states   Etats-Unis
# 238257  en:united-states   Etats-Unis
#
#                                          ingredients_text  \
# 408                               Mediterranean sea salt.
# 3037    Salt, yellow prussiate of soda (anti-caking ag...
# 6375                                            Sea salt.
# 16704                             Mediterranean sea salt.
# 16940                                 Himalayan pink salt
# ...                                                   ...
# 156930                                          Sea salt.
# 194138  Farine de _blé_ T65*, _Œufs_ entiers*, sucre d...
# 194811                                   Sel marin moulu.
# 223450                Natural dead sea salt, organic dill
# 238257  Grey salt from guerande, dried white truffles ...
#
#                     allergens                                      traces  \
# 408                       NaN                                         NaN
# 3037                      NaN                                         NaN
# 6375                      NaN                                         NaN
# 16704                     NaN                                         NaN
# 16940                     NaN                                         NaN
# ...                       ...                                         ...
# 156930                    NaN                                         NaN
# 194138  blé, Œufs, soja, lait  Fruits à coque,Arachides,Graines de sésame
# 194811                    NaN                                         NaN
# 223450                    NaN                                         NaN
# 238257                    NaN                                         NaN
#
#                                traces_tags  \
# 408                                    NaN
# 3037                                   NaN
# 6375                                   NaN
# 16704                                  NaN
# 16940                                  NaN
# ...                                    ...
# 156930                                 NaN
# 194138  en:nuts,en:peanuts,en:sesame-seeds
# 194811                                 NaN
# 223450                                 NaN
# 238257                                 NaN
#
#                                          traces_fr      serving_size  \
# 408                                            NaN  1.2 g (0.25 tsp)
# 3037                                           NaN  1.2 g (0.25 tsp)
# 6375                                           NaN  1.4 g (0.25 tsp)
# 16704                                          NaN  1.2 g (0.25 tsp)
# 16940                                          NaN    1 g (0.25 tsp)
# ...                                            ...               ...
# 156930                                         NaN  1.2 g (0.25 tsp)
# 194138  Fruits à coque,Arachides,Graines de sésame              27 g
# 194811                                         NaN               NaN
# 223450                                         NaN  1.4 g (0.25 tsp)
# 238257                                         NaN         1 g (1 g)
#
#         additives_n                                          additives  \
# 408             0.0   [ mediterranean-sea-salt -> en:mediterranean-...
# 3037            1.0   [ salt -> en:salt  ]  [ yellow-prussiate-of-s...
# 6375            0.0   [ sea-salt -> en:sea-salt  ]  [ salt -> en:sa...
# 16704           0.0   [ mediterranean-sea-salt -> en:mediterranean-...
# 16940           0.0   [ himalayan-pink-salt -> en:himalayan-pink-sa...
# ...             ...                                                ...
# 156930          0.0   [ sea-salt -> en:sea-salt  ]  [ salt -> en:sa...
# 194138          4.0   [ farine-de-ble-t65 -> fr:farine-de-ble-t65  ...
# 194811          0.0   [ sel-marin-moulu -> fr:sel-marin-moulu  ]  [...
# 223450          0.0   [ natural-dead-sea-salt -> en:natural-dead-se...
# 238257          0.0   [ grey-salt-from-guerande -> en:grey-salt-fro...
#
#                          additives_tags  \
# 408                                 NaN
# 3037                            en:e535
# 6375                                NaN
# 16704                               NaN
# 16940                               NaN
# ...                                 ...
# 156930                              NaN
# 194138  en:e422,en:e322,en:e500,en:e415
# 194811                              NaN
# 223450                              NaN
# 238257                              NaN
#
#                                              additives_fr  \
# 408                                                   NaN
# 3037                        E535 - Ferrocyanure de sodium
# 6375                                                  NaN
# 16704                                                 NaN
# 16940                                                 NaN
# ...                                                   ...
# 156930                                                NaN
# 194138  E422 - Glycérol,E322 - Lécithines,E500 - Carbo...
# 194811                                                NaN
# 223450                                                NaN
# 238257                                                NaN
#
#         ingredients_from_palm_oil_n ingredients_from_palm_oil_tags  \
# 408                             0.0                            NaN
# 3037                            0.0                            NaN
# 6375                            0.0                            NaN
# 16704                           0.0                            NaN
# 16940                           0.0                            NaN
# ...                             ...                            ...
# 156930                          0.0                            NaN
# 194138                          0.0                            NaN
# 194811                          0.0                            NaN
# 223450                          0.0                            NaN
# 238257                          0.0                            NaN
#
#         ingredients_that_may_be_from_palm_oil_n  \
# 408                                         0.0
# 3037                                        0.0
# 6375                                        0.0
# 16704                                       0.0
# 16940                                       0.0
# ...                                         ...
# 156930                                      0.0
# 194138                                      0.0
# 194811                                      0.0
# 223450                                      0.0
# 238257                                      0.0
#
#        ingredients_that_may_be_from_palm_oil_tags nutrition_grade_fr  \
# 408                                           NaN                NaN
# 3037                                          NaN                NaN
# 6375                                          NaN                NaN
# 16704                                         NaN                NaN
# 16940                                         NaN                NaN
# ...                                           ...                ...
# 156930                                        NaN                  c
# 194138                                        NaN                  e
# 194811                                        NaN                  c
# 223450                                        NaN                  c
# 238257                                        NaN                NaN
#
#         pnns_groups_1       pnns_groups_2  \
# 408               NaN                 NaN
# 3037              NaN                 NaN
# 6375              NaN                 NaN
# 16704             NaN                 NaN
# 16940             NaN                 NaN
# ...               ...                 ...
# 156930            NaN                 NaN
ruits-vegetables-nuts_100g  collagen-meat-protein-ratio_100g  \
# 408                             NaN                               NaN
# 3037                            NaN                               NaN
# 6375                            NaN                               NaN
# 16704                           NaN                               NaN
# 16940                           NaN                               NaN
# ...                             ...                               ...
# 156930                          NaN                               NaN
# 194138                          NaN                               NaN
# 194811                          NaN                               NaN
# 223450                          NaN                               NaN
# 238257                          NaN                               NaN
#
#         cocoa_100g  carbon-footprint_100g  nutrition-score-fr_100g  \
# 408            NaN                    NaN                      NaN
# 3037           NaN                    NaN                      NaN
# 6375           NaN                    NaN                      NaN
# 16704          NaN                    NaN                      NaN
# 16940          NaN                    NaN                      NaN
# ...            ...                    ...                      ...
# 156930         NaN                    NaN                     10.0
# 194138         NaN                    NaN                     22.0
# 194811         NaN                    NaN                     10.0
# 223450         NaN                    NaN                     10.0
# 238257         NaN                    NaN                      NaN
#
#         nutrition-score-uk_100g
# 408                         NaN
# 3037                        NaN
# 6375                        NaN
# 16704                       NaN
# 16940                       NaN
# ...                         ...
# 156930                     10.0
# 194138                     22.0
# 194811                     10.0
# 223450                     10.0
# 238257                      NaN
#
# [96 rows x 141 columns]

# %% [markdown]
# On retrouve des sels dans les valeurs > 100.
#
# Ils se caractérisent par une absence d'énergie.
#
# On va pouvoir les corriger ainsi.
#
# Le sodium sera recalculé via le sel.

# %%
def salt_sodium_corr(df):
    
    # Quand c'est du sel.
    salt_condition = (df["salt_100g"] > 100) & ((df["energy_100g"] == 0) | df["energy_100g"].isnull())

    mask = copy.deepcopy(df)
    
    # On met à 100g
    df.loc[salt_condition, "salt_100g"] = 100
    
    # Quand c'est supérieur à 100
    minimum = df.loc[df["salt_100g"] > 0, "salt_100g"].min()
    condition = (df["salt_100g"] > 100) & (df["salt_100g"]/1000 > minimum)
    df.loc[condition, "salt_100g"] = df.loc[condition, "salt_100g"]/1000
    
    # On recalcul le sodium avec le ratio
    ratio_moyenne = df["sodium_100g"].mean()/df["salt_100g"].mean()

    df["sodium_100g"] = df["salt_100g"] * ratio_moyenne
    
    # Test statistique
    resultcorrection_ttest(mask, df, "sodium_100g", False)
    
    # Test statistique
    resultcorrection_ttest(mask, df, "salt_100g", False)
    
    df = ajustement(df, "salt_100g")
    
    # On récupère les index où il n'y a pas de valeur entrées pour les salt
    index_nulle_salt = df.loc[df["salt_100g"].isnull()].index
    
    print("Il y a %d valeurs nulles." %index_nulle_salt.shape[0])
 
    
    return df

# %%
display(data[["salt_100g", "sodium_100g"]].describe())

data = salt_sodium_corr(data)

display(data[["salt_100g", "sodium_100g"]].describe())
# Out:
#            salt_100g    sodium_100g
# count  241591.000000  241551.000000
# mean        1.594149       0.627719
# std         6.382494       2.512957
# min         0.000000       0.000000
# 25%         0.068580       0.027000
# 50%         0.589280       0.232000
# 75%         1.361440       0.536000
# max       254.000000     100.000000
# Il y a 9844 valeurs nulles.
#            salt_100g    sodium_100g
# count  241591.000000  241591.000000
# mean        1.581431       0.627719
# std         6.192190       2.457871
# min         0.000000       0.000000
# 25%         0.068580       0.027222
# 50%         0.589280       0.233903
# 75%         1.361440       0.540398
# max       100.000000      39.693088

# %% [markdown]
# On a pu corriger les valeurs aberrantes.
#
# Il reste des valeurs nulles, que nous tenterons de compléter par la suite.

# %%
figure_feature(data, "salt_100g")
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %% [markdown]
# La majorité des produits sont pauvres en sel.

# %% [markdown]
# #### <a name = "T3C8">8. Valeurs extrêmes : somme des macro-éléments</a>

# %% [markdown]
# Si on fait la somme des macro-éléments, il n'est pas possible que cette valeur soit supérieure à 100g
#
# On va donc rechercher les produits où on retrouve ces aberrations.

# %%
#Liste contenant les noms des macro-éléments
macro = [ 
'fat_100g',
 'carbohydrates_100g',
 'proteins_100g',
 'salt_100g',
]

# %%
# On recherche les features où il y a des valeurs aberrantes et on garde les indexes en mémoire
# On s'intéresse aux macro nutriments, car importants pour les calculs de nutriscore

somme_pos = []
# On analyse l'erreur entre la somme des macros entre 100 et 110
for i in range(101,111):
    somme_pos.append([i, data[data[macro].sum(axis = 1) > i].shape[0]])
       
# On transforme en DataFrame    
somme_pos = pd.DataFrame(somme_pos, columns = ["Somme", "Nombre"])
display(somme_pos)
# Out:
#    Somme  Nombre
# 0    101    2682
# 1    102    2092
# 2    103    1750
# 3    104    1480
# 4    105    1285
# 5    106    1151
# 6    107    1046
# 7    108     938
# 8    109     848
# 9    110     786

# %% [markdown]
# Si on accepte 0 % erreurs, 4000 lignes sont éliminées.
#
# Si on accepte 10 % d'erreurs, 7 fois moins de lignes sont éliminées.
#
# L'erreur étant minimime. On accepte 10 % d'erreur.

# %%
def sommeplus (df):
    macro = ['fat_100g', 'carbohydrates_100g', 'proteins_100g', 'salt_100g']
    # On recherche les produits où la somme des valeurs macros est > 110
    
    mask = copy.deepcopy(df)
    
    index_macro = df[df[macro].sum(axis = 1) > 110].index

    df = df[~df.index.isin(index_macro)]

    print(index_macro.shape[0], "lignes sont éliminées")
    
    # Test statistique
    for element in macro:
        resultcorrection_ttest(mask, df, element, False)
    
    return df

# %%
data = sommeplus(data)
# Out:
# 786 lignes sont éliminées

# %% [markdown]
# 786 lignes ont été supprimées à la suite de cette opération.
#
# Ces élimination n'entraînent pas de modification significative de la distribution.

# %%
df = pd.DataFrame(data[macro].sum(axis = 1), columns = ["Sum"])
df.describe()
# Out:
#                  Sum
# count  250649.000000
# mean       51.098056
# std        33.740980
# min         0.000000
# 25%        18.960860
# 50%        47.700000
# 75%        86.965200
# max       110.000000

# %%
figure_feature(df, "Sum")
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %% [markdown]
# Il y a 3 types de produits.
# - Pauvres en macro nutriment < 30g/100g
# - Intermédiaires en macro nutriments > 30 et < 80 g/100g
# - Très riches en macro nutriments > 80 g/100g

# %%
# Affichons les proteins
figure_feature(data, "proteins_100g")
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %% [markdown]
# Il semblerait que ce soit les carbohydrates qui contribuent le plus au haut de la distribution

# %% [markdown]
# #### <a name = "T3C9">9. Correction et remplissage d'energy-from-fat_100g </a>

# %%
print("Nombre de valeurs manquantes :",data["energy-from-fat_100g"].isnull().sum())
display(data["energy-from-fat_100g"].describe())
# Out:
# Nombre de valeurs manquantes : 249813
# count     836.000000
# mean      565.361112
# std       693.596901
# min         0.000000
# 25%        45.850000
# 50%       296.000000
# 75%       888.500000
# max      3830.000000
# Name: energy-from-fat_100g, dtype: float64

# %% [markdown]
# La feature est très peu remplie, mais elle est facilement remplissable.
#
# En effet, 1g de fat correspond à 37,7 kJ.
#
# Si on mesure le ratio actuel.

# %%
data.loc[data["energy-from-fat_100g"].notnull(), "energy-from-fat_100g"].sum()/data.loc[data["energy-from-fat_100g"].notnull(), "fat_100g"].sum()
# Out:
# 37.09314191640908

# %% [markdown]
# On est éloigné de la valeur théorique. Ce qui veut dire qu'il y a des erreurs d'entrées.

# %%
(data.loc[data["energy-from-fat_100g"].notnull(), "energy-from-fat_100g"]/data.loc[data["energy-from-fat_100g"].notnull(), "fat_100g"]).describe()
# Out:
# count    674.000000
# mean            inf
# std             NaN
# min        0.000000
# 25%       35.914889
# 50%       37.493017
# 75%       41.899265
# max             inf
# dtype: float64

# %% [markdown]
# On va recalculer pour tout les produits.

# %%
## Fonction permettant de mesurer energy-from-fat_100g

def energy_fat(df):

    null_avant = df[df["energy-from-fat_100g"].isnull()].index
    
    mask = copy.deepcopy(df)
    
    #On fait la quantité de fat * 37,7 joules
    df["energy-from-fat_100g"] = df["fat_100g"] * 37.7
    
    null_apres = df[df["energy-from-fat_100g"].isnull()].index

    # Test statistique
    resultcorrection_ttest(mask[~mask.index.isin(null_avant)], df[~df.index.isin(null_avant)], "energy-from-fat_100g", False)

    print(null_avant.shape[0] - null_apres.shape[0],"données ont pu être rempli. Il en reste",null_apres.shape[0]," incomplètes")
    
    return df

# %%
data = energy_fat(data)

display(data["energy-from-fat_100g"].describe())
# Out:
# 243531 données ont pu être rempli. Il en reste 6282  incomplètes
# count    244367.000000
# mean        460.057299
# std         625.921737
# min           0.000000
# 25%           3.770000
# 50%         188.500000
# 75%         736.846500
# max        3770.000000
# Name: energy-from-fat_100g, dtype: float64

# %%
data["fat_100g"].corr(data["energy-from-fat_100g"])
# Out:
# 0.9999999999999983

# %% [markdown]
# Ce résultat est normal étant donné que nous avons mesuré l'énergy via la quantité de fat

# %%
# on peut le confirmer visuellement.

figure_feature(data, "fat_100g")
figure_feature(data, "energy-from-fat_100g")
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %% [markdown]
# #### <a name = "T3C10">10. Correction et remplissage d'energy_100g </a>

# %%
print("Nombre de valeurs manquantes :",data["energy_100g"].isnull().sum())
display(data["energy_100g"].describe())
# Out:
# Nombre de valeurs manquantes : 4400
# count    2.462490e+05
# mean     1.142746e+03
# std      6.630745e+03
# min      0.000000e+00
# 25%      3.890000e+02
# 50%      1.100000e+03
# 75%      1.674000e+03
# max      3.251373e+06
# Name: energy_100g, dtype: float64

# %% [markdown]
# Il y a très peu de valeurs manquantes. Cependant, on peut observer des valeurs à 0.

# %%
figure_feature(data, "energy_100g")
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %% [markdown]
# On peut re-calculer les valeurs manquantes ou aberrantes pour la feature "energy_100g".
#
# **Pour 1 g de protéine ou de carbohydrate on obtient 16.7 kJ d'énergie et pour 1 g de fat, on obtient 37.7 kJ d'énergie**

# %%
## Fonction pour calculer l'énergie
def energy_calcul(df):

    energy = ['fat_100g', 'carbohydrates_100g', 'proteins_100g']

    cond1 = (df["energy_100g"].isnull()) # Si la valeur est nulle
    cond2 = (df["energy_100g"] < df["energy-from-fat_100g"]) # si la valeur est aberrante
    cond3 = (df["energy_100g"] > 3770) # Quand valeur supérieure au maximum théoorique
    cond4 = (df["energy_100g"] == 0) # Quand valeur = 0, on recalcul
    cond_final = (df[energy].sum(axis = 1) > 0) # Si la valeur est mesurable

    mask = copy.deepcopy(df)
    
    print("Nombre de valeurs aberrantes ", df[(cond1|cond2|cond3|cond4)].shape[0])
    print("null : ", df[cond1].shape[0],
         "<Nfat : ", df[cond2].shape[0],
         ">3770 : ", df[cond3].shape[0],
         "==0 : ", df[cond4].shape[0],
         "\n")
    print("Nombre de valeurs qui seront corrigées ", df[(cond1|cond2|cond3|cond4) & cond_final].shape[0])
    print("null : ", df[cond1 & cond_final].shape[0],
         "<Nfat : ", df[cond2 & cond_final].shape[0],
         ">3770 : ", df[cond3 & cond_final].shape[0],
         "==0 : ", df[cond4 & cond_final].shape[0],
         "\n")
    print("Nombre de valeurs qui resteront non-corrigées ", df[(cond1|cond2|cond3|cond4) & ~cond_final].shape[0])
    print("null : ", df[cond1 & ~cond_final].shape[0],
         "<Nfat : ", df[cond2 & ~cond_final].shape[0],
         ">3770 : ", df[cond3 & ~cond_final].shape[0],
         "==0 : ", df[cond4 & ~cond_final].shape[0],
         "\n")
    
    df.loc[(cond1|cond2|cond3|cond4) & cond_final, "energy_100g"] =( 
[(x[0]*37.7 if x[0] > 0 else 0) 
 + (x[1]*16.7 if x[1] > 0 else 0) 
 + (x[2]*16.7 if x[2] > 0 else 0) 
 for x in np.array(df.loc[(cond1|cond2|cond3|cond4) & cond_final, ['fat_100g',  'carbohydrates_100g', 'proteins_100g']])])
    
    # Test statistique
    resultcorrection_ttest(mask, df, "energy_100g", False)
    
    print("Nombre de valeurs nulles restantes ", df[cond1].shape[0])
    
    return df

# %%
data = energy_calcul(data)
# Out:
# Nombre de valeurs aberrantes  15877
# null :  4400 <Nfat :  3828 >3770 :  306 ==0 :  7393
#
# Nombre de valeurs qui seront corrigées  6390
# null :  1105 <Nfat :  3828 >3770 :  294 ==0 :  1213
#
# Nombre de valeurs qui resteront non-corrigées  9487
# null :  3295 <Nfat :  0 >3770 :  12 ==0 :  6180
#
# Nombre de valeurs nulles restantes  4400

# %%
figure_feature(data, "energy_100g")
display(data["energy_100g"].describe())
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))
# count    247354.000000
# mean       1130.457918
# std         786.827284
# min           0.000000
# 25%         393.000000
# 50%        1109.000000
# 75%        1674.000000
# max       11954.000000
# Name: energy_100g, dtype: float64

# %%
with pd.option_context('display.max_columns', None):
    display(data[data["energy_100g"]>4000][['energy_100g','fat_100g', 'carbohydrates_100g', 'proteins_100g', 'salt_100
# 4874                        NaN         NaN             NaN    NaN        US
# 25157                       NaN         NaN             NaN    NaN        US
# 71049                       NaN         NaN             NaN    NaN        US
# 81474                       NaN         NaN             NaN    NaN        US
# 83268                       NaN         NaN             NaN    NaN        US
# 83269                       NaN         NaN             NaN    NaN        US
# 100931                      NaN         NaN             NaN    NaN        US
# 106652                      NaN         NaN             NaN    NaN        US
# 107990                      NaN         NaN             NaN    NaN        US
# 116211                      NaN         NaN             NaN    NaN        US
# 117700                      NaN         NaN             NaN    NaN        US
# 158070                      NaN         NaN             NaN    NaN    France
#
#           countries_tags countries_fr  \
# 4874    en:united-states   Etats-Unis
# 25157   en:united-states   Etats-Unis
# 71049   en:united-states   Etats-Unis
# 81474   en:united-states   Etats-Unis
# 83268   en:united-states   Etats-Unis
# 83269   en:united-states   Etats-Unis
# 100931  en:united-states   Etats-Unis
# 106652  en:united-states   Etats-Unis
# 107990  en:united-states   Etats-Unis
# 116211  en:united-states   Etats-Unis
# 117700  en:united-states   Etats-Unis
# 158070         en:france       France
#
#                                          ingredients_text allergens traces  \
# 4874      Vinegar, water, mustard seed, salt, red pepper.       NaN    NaN
# 25157   Canola oil, lecithin from soybeans, rosemary e...       NaN    NaN
# 71049   Salt, sodium diacetate, spices, dehydrated gar...       NaN    NaN
# 81474                                     Mustard powder.       NaN    NaN
# 83268                       Fresh oregano, sunflower oil.       NaN    NaN
# 83269                        Fresh lemons, sunflower oil.       NaN    NaN
# 100931  Canola oil, lecithin from soybeans, natural bu...       NaN    NaN
# 106652  Onion, sundried tomato, sea salt, basil, red b...       NaN    NaN
# 107990                                      Annatto seed.       NaN    NaN
# 116211                                   Star anise seed.       NaN    NaN
# 117700  Sea salt, spices and herbs, natural bleu chees...       NaN    NaN
# 158070                                                NaN       NaN    NaN
#
#        traces_tags traces_fr             serving_size  additives_n  \
# 4874           NaN       NaN              5 g (1 tsp)          0.0
# 25157          NaN       NaN  0.3 g (0.25 SEC. SPRAY)          0.0
# 71049          NaN       NaN         0.7 g (0.25 tsp)          3.0
# 81474          NaN       NaN        0.5 g (0.25 Tbsp)          0.0
# 83268          NaN       NaN      0.375 ml (3 SPRAYS)          0.0
# 83269          NaN       NaN      0.375 ml (3 SPRAYS)          0.0
# 100931         NaN       NaN  0.3 g (0.25 SEC. SPRAY)          1.0
# 106652         NaN       NaN              2 g (2 GRM)          0.0
# 107990         NaN       NaN         0.5 g (0.5 Tbsp)          0.0
# 116211         NaN       NaN            14 g (0.5 oz)          0.0
# 117700         NaN       NaN        0.75 g (0.25 tsp)          0.0
# 158070         NaN       NaN                      NaN          NaN
#
#                                                 additives  \
# 4874     [ vinegar -> en:vinegar  ]  [ water -> en:wat...
# 25157    [ canola-oil -> en:canola-oil  ]  [ oil -> en...
# 71049    [ salt -> en:salt  ]  [ sodium-diacetate -> e...
# 81474    [ mustard-powder -> en:mustard-powder  ]  [ p...
# 83268    [ fresh-oregano -> en:fresh-oregano  ]  [ ore...
# 83269    [ fresh-lemons -> en:fresh-lemons  ]  [ lemon...
# 100931   [ canola-oil -> en:canola-oil  ]  [ oil -> en...
# 106652   [ onion -> en:onion  ]  [ sundried-tomato -> ...
# 107990   [ annatto-seed -> en:annatto-seed  ]  [ seed ...
# 116211   [ star-anise-seed -> en:star-anise-seed  ]  [...
# 117700   [ sea-salt -> en:sea-salt  ]  [ salt -> en:sa...
# 158070                                                NaN
#
#                     additives_tags  \
# 4874                           NaN
# 25157                          NaN
# 71049   en:e262ii,en:e160b,en:e341
# 81474                          NaN
# 83268                          NaN
# 83269                          NaN
# 100931                    en:e160b
# 106652                         NaN
# 107990                         NaN
# 116211                         NaN
# 117700                         NaN
# 158070                         NaN
#
#                                              additives_fr  \
# 4874                                                  NaN
# 25157                                                 NaN
# 71049   E262ii,E160b - Rocou,E341 - Phosphate de calci...
# 81474                                                 NaN
# 83268                                                 NaN
# 83269                                                 NaN
# 100931                                      E160b - Rocou
# 106652                                                NaN
# 107990                                                NaN
# 116211                                                NaN
# 117700                                                NaN
# 158070                                                NaN
#
#         ingredients_from_palm_oil_n ingredients_from_palm_oil_tags  \
# 4874                            0.0                            NaN
# 25157                           0.0                            NaN
# 71049                           0.0                            NaN
# 81474                           0.0                            NaN
# 83268                           0.0                            NaN
# 83269                           0.0                            NaN
# 100931                          0.0                            NaN
# 106652                          0.0                            NaN
# 107990                          0.0                            NaN
# 116211                          0.0                            NaN
# 117700                          0.0                            NaN
# 158070                          NaN                            NaN
#
#         ingredients_that_may_be_from_palm_oil_n  \
# 4874                                        0.0
# 25157                                       0.0
# 71049                                       0.0
# 81474                                       0.0
# 83268                                       0.0
# 83269                                       0.0
# 100931                                      0.0
# 106652                                      0.0
# 107990                                      0.0
# 116211                                      0.0
# 117700                                      0.0
# 158070                                      NaN
#
#        ingredients_that_may_be_from_palm_oil_tags nutrition_grade_fr  \
# 4874                                          NaN                NaN
# 25157                                         NaN                NaN
# 71049                                         NaN                NaN
# 81474                                         NaN                NaN
# 83268                                         NaN                NaN
# 83269                                         NaN                NaN
# 100931                                        NaN                NaN
# 106652                                        NaN                NaN
# 107990                                        NaN                  c
# 116211                                        NaN                  c
# 117700                                        NaN                NaN
# 158070                                        NaN                  c
#
#        pnns_groups_1 pnns_groups_2  \
# 4874             NaN           NaN
# 25157            NaN           NaN
# 71049            NaN           NaN
# 81474            NaN           NaN
# 83268            NaN           NaN
# 83269            NaN           NaN
# 100931           NaN           NaN
# 106652           NaN           NaN
# 107990           NaN           NaN
# 116211           NaN           NaN
# 117700           NaN           NaN
# 158070           NaN           NaN
#
#                                                    states  \
# 4874    en:to-be-completed, en:nutrition-facts-complet...
# 25157   en:to-be-completed, en:nutrition-facts-complet...
# 71049   en:to-be-completed, en:nutrition-facts-complet...
# 81474   en:to-be-completed, en:nutrition-facts-complet...
# 83268   en:to-be-completed, en:nutrition-facts-complet...
# 83269   en:to-be-completed, en:nutrition-facts-complet...
# 100931  en:to-be-completed, en:nutrition-facts-complet...
# 106652  en:to-be-completed, en:nutrition-facts-complet...
# 107990  en:to-be-completed, en:nutrition-facts-complet...
# 116211  en:to-be-completed, en:nutrition-facts-complet...
# 117700  en:to-be-completed, en:nutrition-facts-complet...
odine_100g  caffeine_100g  taurine_100g  ph_100g  \
# 4874            NaN            NaN           NaN      NaN
# 25157           NaN            NaN           NaN      NaN
# 71049           NaN            NaN           NaN      NaN
# 81474           NaN            NaN           NaN      NaN
# 83268           NaN            NaN           NaN      NaN
# 83269           NaN            NaN           NaN      NaN
# 100931          NaN            NaN           NaN      NaN
# 106652          NaN            NaN           NaN      NaN
# 107990          NaN            NaN           NaN      NaN
# 116211          NaN            NaN           NaN      NaN
# 117700          NaN            NaN           NaN      NaN
# 158070          NaN            NaN           NaN      NaN
#
#         fruits-vegetables-nuts_100g  collagen-meat-protein-ratio_100g  \
# 4874                            NaN                               NaN
# 25157                           NaN                               NaN
# 71049                           NaN                               NaN
# 81474                           NaN                               NaN
# 83268                           NaN                               NaN
# 83269                           NaN                               NaN
# 100931                          NaN                               NaN
# 106652                          NaN                               NaN
# 107990                          NaN                               NaN
# 116211                          NaN                               NaN
# 117700                          NaN                               NaN
# 158070                          NaN                               NaN
#
#         cocoa_100g  carbon-footprint_100g  nutrition-score-fr_100g  \
# 4874           NaN                    NaN                      NaN
# 25157          NaN                    NaN                      NaN
# 71049          NaN                    NaN                      NaN
# 81474          NaN                    NaN                      NaN
# 83268          NaN                    NaN                      NaN
# 83269          NaN                    NaN                      NaN
# 100931         NaN                    NaN                      NaN
# 106652         NaN                    NaN                      NaN
# 107990         NaN                    NaN                     10.0
# 116211         NaN                    NaN                     10.0
# 117700         NaN                    NaN                      NaN
# 158070         NaN                    NaN                     10.0
#
#         nutrition-score-uk_100g
# 4874                        NaN
# 25157                       NaN
# 71049                       NaN
# 81474                       NaN
# 83268                       NaN
# 83269                       NaN
# 100931                      NaN
# 106652                      NaN
# 107990                     10.0
# 116211                     10.0
# 117700                      NaN
# 158070                     10.0

# %% [markdown]
# Ce sont soient des huiles, soit du sel.
#
# Il n'y a pas d'informations nutritionnelles
#
# Etant donné que ça concerne peu de produits, on les enlève.

# %%
data = data[data["energy_100g"]<4000]

# %%
figure_feature(data, "energy_100g")
display(data["energy_100g"].describe())
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))
# count    247342.000000
# mean       1130.224349
# std         785.999757
# min           0.000000
# 25%         393.000000
# 50%        1109.000000
# 75%        1674.000000
# max        3889.238000
# Name: energy_100g, dtype: float64

# %% [markdown]
# Très peu de produits riches en énergie.

# %% [markdown]
# #### <a name = "T3C11">11. Différence entre energy_100g mesurée et entrée </a>

# %% [markdown]
# En connaissant la quantité de Fat, Proteins et Sugars, on est sensé pouvoir trouver la valeur d'energy_100g.
#
# En la remesurant, on fait donc l'hypothèse que la différence entre théorique et entrée soit faible.
#
# Pour comparer, nous faisons sur les valeurs entrées > 0 et où on retrouve une valeur pour les 3 macros.

# %%
macro_nrj = ['fat_100g', 'carbohydrates_100g', 'proteins_100g']
cond1 = (data[macro_nrj].count(axis = 1) == 3) # 3 valeurs non nulles
cond2 = (data["energy_100g"].notnull()) # valeur energy non nulle

data[cond1 & cond2].shape[0]
# Out:
# 241645

# %%
# On prend un slice du dataframe
dt = copy.deepcopy(data[cond1 & cond2])

dt["energy_100g"] =( 
[(x[0]*37.7 if x[0] > 0 else 0) 
 + (x[1]*16.7 if x[1] > 0 else 0) 
 + (x[2]*16.7 if x[2] > 0 else 0) 
 for x in np.array(dt[macro_nrj])])

# %%
display(data["energy_100g"].describe())
display(dt["energy_100g"].describe())
figure_feature(data, "energy_100g")
figure_feature(data, "energy_100g")
# Out:
# count    247342.000000
# mean       1130.224349
# std         785.999757
# min           0.000000
# 25%         393.000000
# 50%        1109.000000
# 75%        1674.000000
# max        3889.238000
# Name: energy_100g, dtype: float64
# count    241645.000000
# mean       1102.381055
# std         790.199414
# min           0.000000
# 25%         360.490000
# 50%        1062.099000
# 75%        1666.989000
# max        3889.238000
# Name: energy_100g, dtype: float64
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %%
#On mesure la différence entre la valeur de la base de données et la valeur calculée
dif = pd.DataFrame({"variation" : data[cond1 & cond2]["energy_100g"] - dt["energy_100g"]})

display(dif.describe())
# Out:
#            variation
# count  241645.000000
# mean       32.667095
# std       228.458093
# min     -1655.810000
# 25%       -17.536000
# 50%         1.803000
# 75%        27.240000
# max      3556.000000

# %% [markdown]
# On affiche la dispersion de la différence.

# %%
figure_feature(dif, "variation")
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %% [markdown]
# L'alcool pourrait contribuer à sous-estimer l'énergie.
#
# 1 g d'alcool équivaut à 29.3kJ.

# %%
data.loc[(data["alcohol_100g"].notnull()) & (data["alcohol_100g"]>0), ['energy_100g','fat_100g', 'carbohydrates_100g', 'proteins_100g', 'salt_100g',"alcohol_100g"]]
# Out:
#         energy_100g  fat_100g  carbohydrates_100g  proteins_100g  salt_100g  \
# 98811         832.0       NaN                 NaN            NaN        NaN
# 98812         856.0       NaN                 NaN            NaN        NaN
# 98813         860.0       NaN                 NaN            NaN        NaN
# 98921         169.0       NaN                2.94          0.361        NaN
# 99172         145.0       0.0               10.60          1.300        NaN
# ...             ...       ...                 ...            ...        ...
# 255235        276.0       NaN                 NaN          7.000        NaN
# 255236        276.0       NaN                 NaN          7.000        NaN
# 255745       2775.0      58.0               13.00         21.000       0.55
# 255746       2775.0      58.0               13.00         21.000       0.55
# 255747       2775.0      58.0               13.00         21.000       0.55
#
#         alcohol_100g
# 98811           36.0
# 98812           37.5
# 98813           37.5
# 98921            5.0
# 99172            5.0
# ...              ...
# 255235           7.0
# 255236           7.0
# 255745          12.0
# 255746          12.0
# 255747          12.0
#
# [231 rows x 6 columns]

# %%
dt.loc[(dt["alcohol_100g"].notnull()) & (dt["alcohol_100g"]>0), ['energy_100g','fat_100g', 'carbohydrates_100g', 'proteins_100g', 'salt_100g',"alcohol_100g"]]
# Out:
#         energy_100g  fat_100g  carbohydrates_100g  proteins_100g  salt_100g  \
# 99172      198.7300       0.0               10.60          1.300        NaN
# 100207      68.7038       0.0                3.82          0.294       0.00
# 117617      27.8556       0.0                1.39          0.278        NaN
# 155501     165.3300       0.0                9.90          0.000       0.01
# 155732     165.3300       0.0                9.90          0.000       0.01
# ...             ...       ...                 ...            ...        ...
# 252574      80.1600       0.0                4.00          0.800        NaN
# 252575      80.1600       0.0                4.00          0.800        NaN
# 255745    2754.4000      58.0               13.00         21.000       0.55
# 255746    2754.4000      58.0               13.00         21.000       0.55
# 255747    2754.4000      58.0               13.00         21.000       0.55
#
#         alcohol_100g
# 99172            5.0
# 100207           4.7
# 117617           4.2
# 155501           0.1
# 155732           0.1
# ...              ...
# 252574           8.0
# 252575           8.0
# 255745          12.0
# 255746          12.0
# 255747          12.0
#
# [164 rows x 6 columns]

# %%
# On prend un slice du dataframe
dt_alcool = copy.deepcopy(data[cond1 & cond2])

dt_alcool["energy_100g"] =( 
[(x[0]*37.7 if x[0] > 0 else 0) 
 + (x[1]*16.7 if x[1] > 0 else 0) 
 + (x[2]*16.7 if x[2] > 0 else 0) 
 + (x[3]*29.3 if x[3] > 0 else 0) 
 for x in np.array(dt_alcool[macro_nrj + ["alcohol_100g"]])])
    
#On mesure la différence entre la valeur de la base de données et la valeur calculée
dif_alcool = pd.DataFrame({"variation" : data[cond1 & cond2]["energy_100g"] - dt_alcool["energy_100g"]})

figure_feature(dif_alcool, "variation")
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %%
dt_alcool.loc[(dt_alcool["alcohol_100g"].notnull()) & (dt_alcool["alcohol_100g"]>0), ['energy_100g','fat_100g', 'carbohydrates_100g', 'proteins_100g', 'salt_100g',"alcohol_100g"]]
# Out:
#         energy_100g  fat_100g  carbohydrates_100g  proteins_100g  salt_100g  \
# 99172      345.2300       0.0               10.60          1.300        NaN
# 100207     206.4138       0.0                3.82          0.294       0.00
# 117617     150.9156       0.0                1.39          0.278        NaN
# 155501     168.2600       0.0                9.90          0.000       0.01
# 155732     168.2600       0.0                9.90          0.000       0.01
# ...             ...       ...                 ...            ...        ...
# 252574     314.5600       0.0                4.00          0.800        NaN
# 252575     314.5600       0.0                4.00          0.800        NaN
# 255745    3106.0000      58.0               13.00         21.000       0.55
# 255746    3106.0000      58.0               13.00         21.000       0.55
# 255747    3106.0000      58.0               13.00         21.000       0.55
#
#         alcohol_100g
# 99172            5.0
# 100207           4.7
# 117617           4.2
# 155501           0.1
# 155732           0.1
# ...              ...
# 252574           8.0
# 252575           8.0
# 255745          12.0
# 255746          12.0
# 255747          12.0
#
# [164 rows x 6 columns]

# %%
display(data["energy_100g"].describe())
display(dt["energy_100g"].describe())
display(dt_alcool["energy_100g"].describe())
display(dif["variation"].describe())
display(dif_alcool["variation"].describe())
# Out:
# count    247342.000000
# mean       1130.224349
# std         785.999757
# min           0.000000
# 25%         393.000000
# 50%        1109.000000
# 75%        1674.000000
# max        3889.238000
# Name: energy_100g, dtype: float64
# count    241645.000000
# mean       1102.381055
# std         790.199414
# min           0.000000
# 25%         360.490000
# 50%        1062.099000
# 75%        1666.989000
# max        3889.238000
# Name: energy_100g, dtype: float64
# count    241645.000000
# mean       1102.557402
# std         790.135542
# min           0.000000
# 25%         360.720000
# 50%        1062.240000
# 75%        1667.050000
# max        4500.060000
# Name: energy_100g, dtype: float64
# count    241645.000000
# mean         32.667095
# std         228.458093
# min       -1655.810000
# 25%         -17.536000
# 50%           1.803000
# 75%          27.240000
# max        3556.000000
# Name: variation, dtype: float64
# count    241645.000000
# mean         32.490749
# std         228.444757
# min       -3515.960000
# 25%         -17.619000
# 50%           1.778000
# 75%          27.140000
# max        3556.000000
# Name: variation, dtype: float64

# %%
data[cond1 & cond2]["energy_100g"]
# Out:
# 0         2243.0
# 1         1941.0
# 2         2540.0
# 3         1552.0
# 4         1933.0
#            ...
# 255946     247.0
# 255947    1538.0
# 255948    1538.0
# 255949    2155.0
# 255950    2155.0
# Name: energy_100g, Length: 241645, dtype: float64

# %%
dt["energy_100g"]
# Out:
# 0         2210.351
# 1         1985.441
# 2         2750.702
# 3         1485.268
# 4         1973.343
#             ...
# 255946     294.755
# 255947    1628.490
# 255948    1628.490
# 255949     382.020
# 255950     382.020
# Name: energy_100g, Length: 241645, dtype: float64

# %%
result_test1 = stats.ttest_rel(data.loc[cond1 & cond2,"energy_100g"], dt["energy_100g"], nan_policy = "omit")
display(result_test1)
result_test2 = stats.ttest_rel(dt["energy_100g"], dt_alcool["energy_100g"])
display(result_test2)
result_test1 = stats.ttest_rel(data.loc[cond1 & cond2,"energy_100g"], dt_alcool["energy_100g"], nan_policy = "omit")
display(result_test1)
# Out:
# Ttest_relResult(statistic=70.28989247168724, pvalue=0.0)
# Ttest_relResult(statistic=-6.724993267608909, pvalue=1.759888045622314e-11)
# Ttest_relResult(statistic=69.91452768533482, pvalue=0.0)

# %% [markdown]
# Ces résultats montrent que la différence entre l'energie théorique et mesurée est significative.
#
# L'ajout de la l'alcool dans la mesure de l'energie est significatif par rapport à la valeur donnée et la valeur mesurée sans alcool.
#
# Les valeurs médianes et interquartiles ne sont pas altérées.
#
# Il y a juste des valeurs extrèmes qui devront être rectifiées.
#
# On réactualise notre fonction.

# %%
## Fonction pour calculer l'énergie
## V2
def energy_calcul(df):

    energy = ['fat_100g', 'carbohydrates_100g', 'proteins_100g', 'alcohol_100g']
    dt_mesure = [(x[0]*37.7 if x[0] > 0 else 0) 
 + (x[1]*16.7 if x[1] > 0 else 0) 
 + (x[2]*16.7 if x[2] > 0 else 0) 
 + (x[3]*29.3 if x[3] > 0 else 0) 
 for x in np.array(df[energy])]
    
    cond1 = (df["energy_100g"].isnull()) # Si la valeur est nulle
    cond2 = (df["energy_100g"] < df["energy-from-fat_100g"]) # si la valeur est aberrante
    cond3 = (df["energy_100g"] > 3770) # Quand valeur supérieure au maximum théoorique
    cond4 = (df["energy_100g"] == 0) # Quand valeur = 0, on recalcul
    cond5 = (abs(df["energy_100g"] - dt_mesure) > 500) # Quand difference > 500
    cond6 = (df[energy].count(axis = 1) >= 3) # quand on a au moins 3 mesures
    cond_final = (df[energy].sum(axis = 1) > 0) # Si la valeur est mesurable

 
    mask = copy.deepcopy(df)
    
    print("Nombre de valeurs aberrantes ", df[(cond1|cond2|cond3|cond4|cond5)].shape[0])
    print("null : ", df[cond1].shape[0],
         "<Nfat : ", df[cond2].shape[0],
         ">3770 : ", df[cond3].shape[0],
         "==0 : ", df[cond4].shape[0],
         "diff > 500 : ", df[cond5].shape[0],
         "\n")
    print("Nombre de valeurs qui seront corrigées ", df[(cond1|cond2|cond3|cond4|(cond5 & cond6)) & cond_final].shape[0])
    print("null : ", df[cond1 & cond_final].shape[0],
         "<Nfat : ", df[cond2 & cond_final].shape[0],
         ">3770 : ", df[cond3 & cond_final].shape[0],
         "==0 : ", df[cond4 & cond_final].shape[0],
         "diff > 500 : ", df[(cond5 & cond6) & cond_final].shape[0],
         "\n")
    print("Nombre de valeurs qui resteront non-corrigées ", df[(cond1|cond2|cond3|cond4|(cond5 & cond6)) & ~cond_final].shape[0])
    print("null : ", df[cond1 & ~cond_final].shape[0],
         "<Nfat : ", df[cond2 & ~cond_final].shape[0],
         ">3770 : ", df[cond3 & ~cond_final].shape[0],
         "==0 : ", df[cond4 & ~cond_final].shape[0],
         "diff > 500 : ", df[(cond5 & cond6) & ~cond_final].shape[0],
         "\n")
    
    df.loc[(cond1|cond2|cond3|cond4|(cond5 & cond6)) & cond_final, "energy_100g"] =( 
[(x[0]*37.7 if x[0] > 0 else 0) 
 + (x[1]*16.7 if x[1] > 0 else 0) 
 + (x[2]*16.7 if x[2] > 0 else 0) 
 + (x[3]*29.3 if x[3] > 0 else 0) 
 for x in np.array(df.loc[(cond1|cond2|cond3|cond4|(cond5 & cond6)) & cond_final, energy])])
    
    df.loc[df["energy_100g"] >3770, "energy_100g"] = 3770 
    # Test statistique
    resultcorrection_ttest(mask, df, "energy_100g", False)
    
    print("Nombre de valeurs nulles restantes ", df[cond1].shape[0])
    
    return df

# %%
data = energy_calcul(data)
# Out:
# Nombre de valeurs aberrantes  16759
# null :  0 <Nfat :  0 >3770 :  956 ==0 :  6180 diff > 500 :  9623
#
# Nombre de valeurs qui seront corrigées  9384
# null :  0 <Nfat :  0 >3770 :  956 ==0 :  2 diff > 500 :  8426
#
# Nombre de valeurs qui resteront non-corrigées  6585
# null :  0 <Nfat :  0 >3770 :  0 ==0 :  6178 diff > 500 :  407
#
# energy_100g : la modification change drastiquement les données, p_value: 1.569375258208576e-36
# Calcul du coefficient de variation :
# Avant traitement =  69.54369348340933
# Après traitement =  70.82129395613997
# Nombre de valeurs nulles restantes  0

# %%
figure_feature(data, "energy_100g")
# Out:
# C:\Users\33664\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %% [markdown]
# La distribution de l'energy est toujours similaire, mais comme le test le montre, la modification est significative, c'est en accord avec les résultats précédents.
#
# Nous n'avons plus de valeurs nulles pour l'énergie.

# %%
# Fonction permettant de créer le fichier csv

def creation_fichier_csv(df,nom_du_fichier):
    
    ## On identifie si le format CSV a été entré, sinon on l'ajout
    if ".csv" not in nom_du_fichier:
        nom_du_fichier = nom_du_fichier + ".csv"
        
    ## Le fichier est écrit au même endroit que le notebook
    ## Séparateur : tab
    df.to_csv(nom_du_fichier, index = False, sep = "\t")

# %% [markdown]
# Nous avons donc des données nettoyées, qu'on peut exporter et ensuite analyser.

# %%
creation_fichier_csv(data, "donnees_nettoyees")

# %%
valeurs_manquantes_graph(data,'column')
